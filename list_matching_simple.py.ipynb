# %%
### ATENTION: ###
#Once this notebook is fully run, the files will be rewritten as desired, that is why it should only be run once, otherwise we take the risk of ending up with the wrong format in our files.

#Additionally, for the purpose of testing or simply having the original files, they will be collected in the directory 'originals'.

#When testing, make sure to change the file paths:
#cityCountry = root + '/Pseudonymization/dataset/originals/cityCountry.csv'
#_cityCountry = root + '/Pseudonymization/dataset/originals/_cityCountry.csv'

# %%
#These functions would only work for the files 'cityCountry.csv' and _cityCountry.csv because 
#of their format (two columns, etc...).

#We will repeat the same steps for both files.

#nº1 cityCountry.csv
#nº2 _cityCountry.csv

# %%
import os
from csv import reader

# %%
#Current working directory: '/home/andrea/repos'
root = os. getcwd()

#Getting absolute path to the files we will be working with
cityCountry = root + '/Pseudonymization/dataset/cityCountry.csv'
_cityCountry = root + '/Pseudonymization/dataset/_cityCountry.csv'

cities_sweden = root + '/Pseudonymization/dataset/cities_sweden.csv'

# %%
#Getting list of countries (in Swedish) using a csv reader

def extracting_countries(filename):
    #Open file in read mode
    with open(filename, 'r') as read_obj:
        swe_countries = []
        #Pass the file object to reader() to get the reader object
        csv_reader = reader(read_obj)
        header = next(csv_reader)
        #print('csv:', csv_reader)
        #Iterate over each row in the csv using reader object
        for row in csv_reader:
            #row variable is a list that represents a row in csv
            #print(row[1])
            if row[1] not in swe_countries: #row[1] == country name
                swe_countries.append(row[1])
    
    return swe_countries

# %%
swe_countries_1 = extracting_countries(cityCountry)
swe_countries_2 = extracting_countries(_cityCountry)

# %%
swe_countries_1
# Out:
# ['Bahamas',
#  'Storbritannien',
#  'Grekland',
#  'Indien',
#  'Tyskland',
#  'Demokratiska Republiken Kongo',
#  'Frankrike',
#  'Filippinerna',
#  'Portugal',
#  'Rumänien',
#  'USA',
#  'Nederländerna',
#  'Belgien',
#  'Mongoliet',
#  'Spanien',
#  'Mexiko',
#  'Ryssland',
#  'Peru',
#  'Slovakien',
#  'Österrike',
#  'Malaysia',
#  'Italien',
#  'Lettland',
#  'Myanmar',
#  'Turkiet',
#  'Brasilien',
#  'Uganda',
#  'Mikronesien',
#  'Venezuela',
#  'Bolivia',
#  'Kina',
#  'Tanzania',
#  'Uzbekistan',
#  'Indonesien',
#  'Schweiz',
#  'Kanada',
#  'Vietnam',
#  'Ungern',
#  'El Salvador',
#  'Polen',
#  'Haiti',
#  'Centralafrikanska republiken',
#  'Kroatien',
#  'Kambodja',
#  'Tunisien',
#  'Tjeckien',
#  'Pakistan',
#  'Dominikanska republiken',
#  'Bulgarien',
#  'Uruguay',
#  'Guatemala',
#  'Armenien',
#  'Slovenien',
#  'Jemen',
#  'Kenya',
#  'Japan',
#  'Australien',
#  'Nigeria',
#  'Serbien',
#  'Albanien',
#  'Ukraina',
#  'Irland',
#  'Luxemburg',
#  'Colombia',
#  'Moçambique',
#  'Ghana',
#  'Irak',
#  'Georgien',
#  'Syrien',
#  'Libyen',
#  'Senegal',
#  'Estland',
#  'Iran',
#  'Vitryssland',
#  'Algeriet',
#  'Kirgizistan',
#  'Argentina',
#  'Marocko',
#  'Afghanistan',
#  'Thailand',
#  'Panama',
#  'Gambia',
#  'Sydafrika',
#  'Finland',
#  'Bosnien och Hercegovina',
#  'Zimbabwe',
#  'Sudan',
#  'Republiken Kongo',
#  'Madagaskar',
#  'Etiopien',
#  'Papua Nya Guinea',
#  'Honduras',
#  'Sydkorea',
#  'Palestina',
#  'Ekvatorialguinea',
#  'Förenade Arabemiraten',
#  'Ecuador',
#  'Mauretanien',
#  'Nepal',
#  'Benin',
#  'Nordkorea',
#  'Dominica',
#  'Paraguay',
#  'Malta',
#  'Israel',
#  'San Marino',
#  'Norge',
#  'Saint Martin',
#  'Sierra Leone',
#  'Puerto Rico',
#  'Kap Verde',
#  'Egypten',
#  'Makedonien',
#  'Nicaragua',
#  'Liberia',
#  'Nya Zeeland',
#  'Elfenbenskusten',
#  'Guinea',
#  'Danmark',
#  'Niger',
#  'Saint Kitts och Nevis',
#  'Azerbajdzjan',
#  'Chile',
#  'Kuba',
#  'Litauen',
#  'Samoa',
#  'Saudiarabien',
#  'Kazakstan',
#  'Kosovo',
#  'Botswana',
#  'Guinea-Bissau',
#  'Tchad',
#  'Montenegro',
#  'Kamerun',
#  'Gabon',
#  'Costa Rica',
#  'Palau',
#  'Djibouti',
#  'Bhutan',
#  'Tadzjikistan',
#  'Västsahara',
#  'Franska Guyana',
#  'Burkina Faso',
#  'Laos',
#  'Angola',
#  'Sri Lanka',
#  'Moldavien',
#  'Cypern',
#  'Guam',
#  'Malawi',
#  'Mali',
#  'Sydsudan',
#  'Kiribati',
#  'Martinique',
#  'Libanon',
#  'Oman',
#  'Turkmenistan',
#  'Somalia',
#  'Swaziland',
#  'Mauritius',
#  'Guadeloupe',
#  'Timor Leste',
#  'Bangladesh',
#  'Grönland',
#  'Tonga',
#  'Maldiverna',
#  'Guernsey',
#  'Bonaire',
#  'Taiwan',
#  'Franska Polynesien',
#  'Grenada',
#  'Togo',
#  'Jamaica',
#  'Jordanien',
#  'Färöarna',
#  'Brunei',
#  'Qatar',
#  'Vanuatu',
#  'Nauru',
#  'Belize',
#  'Andorra',
#  'Nordmarianerna',
#  'Tokelauöarna',
#  'Island',
#  'Zambia',
#  'Barbados',
#  'Komorerna',
#  'Rwanda',
#  'Isle of Man',
#  'Nya Kaledonien',
#  'Åland Islands',
#  'Saint Lucia',
#  'Réunion',
#  'Mayotte',
#  'Caymanöarna',
#  'Lesotho',
#  'Eritrea',
#  'São Tomé och Príncipe',
#  'Guyana',
#  'Amerikanska Samoa',
#  'Wallis och Futuna',
#  'Kuwait',
#  'Hong Kong',
#  'Seychellerna',
#  'Saint Vincent och Grenadinerna',
#  'Bahrain',
#  'Burundi',
#  'Fiji',
#  'Montserrat',
#  'Trinidad och Tobago',
#  'Tuvalu',
#  'Marshallöarna',
#  'Liechtenstein',
#  'Anguilla',
#  'Sydgeorgien och Sydsandwichöarna',
#  'Aruba',
#  'Monaco',
#  'Vatikanstaten',
#  'Surinam',
#  'Antigua och Barbuda',
#  'Sint Maarten',
#  'Pitcairnöarna',
#  'Saint-Pierre och Miquelon',
#  'Macao',
#  'Sankt Helena',
#  'Niue',
#  'Amerikanska Jungfruöarna',
#  'Curaçao',
#  'Singapore',
#  'Gibraltar',
#  'Salomonöarna',
#  'Julön',
#  'Franska södra territorier',
#  'Svalbard',
#  'Brittiska Jungfruöarna',
#  'Jersey',
#  'Bermuda',
#  'Saint Barthélemy',
#  'Cooköarna',
#  'Antarktis',
#  'Kokosöarna',
#  'Turks och Caicosöarna']

# %%
#_____, that is, the output from 'extracting_countries' is translated with Google Translate (manually copying
#and pasting the list here) and it will be saved in variables 'trans_countries_1' and 'trans_countries_2'.

trans_countries_1 = ['Bahamas',
 'UK',
 'Greece',
 'India',
 'Germany',
 'The Democratic Republic of Kongo',
 'France',
 'Philippines',
 'Portugal',
 'Romania',
 'USA',
 'Netherlands',
 'Belgium',
 'Mongolia',
 'Spain',
 'Mexico',
 'Russia',
 'Peru',
 'Slovakia',
 'Austria',
 'Malaysia',
 'Italy',
 'Latvia',
 'Myanmar',
 'Turkey',
 'Brazil',
 'Uganda',
 'Micronesia',
 'Venezuela',
 'Bolivia',
 'China',
 'Tanzania',
 'Uzbekistan',
 'Indonesia',
 'Switzerland',
 'Canada',
 'Vietnam',
 'Hungary',
 'El Salvador',
 'Poland',
 'Haiti',
 'Central African Republic',
 'Croatia',
 'Cambodia',
 'Tunisia',
 'Czech Republic',
 'Pakistan',
 'Dominican Republic',
 'Bulgaria',
 'Uruguay',
 'Guatemala',
 'Armenia',
 'Slovenia',
 'Yemen',
 'Kenya',
 'Japanese',
 'Australia',
 'Nigeria',
 'Serbia',
 'Albania',
 'Ukraine',
 'Ireland',
 'Luxembourg',
 'Colombia',
 'Mozambique',
 'Ghana',
 'Iraq',
 'Georgia',
 'Syria',
 'Libya',
 'Senegal',
 'Estonia',
 'Iran',
 'Belarus',
 'Algeria',
 'Kyrgyzstan',
 'Argentina',
 'Morocco',
 'Afghanistan',
 'Thailand',
 'Panama',
 'Gambia',
 'South Africa',
 'Finland',
 'Bosnia and Herzegovina',
 'Zimbabwe',
 'Sudan',
 'Republic of the Congo',
 'Madagascar',
 'Ethiopia',
 'Papua New Guinea',
 'Honduras',
 'South Korea',
 'Palestine',
 'Equatorial Guinea',
 'United Arab Emirates',
 'Ecuador',
 'Mauritania',
 'Nepal',
 'Benin',
 'North Korea',
 'Dominica',
 'Paraguay',
 'Malta',
 'Israel',
 'San Marino',
 'Norway',
 'Saint Martin',
 'Sierra Leone',
 'Puerto Rico',
 'Cape Verde',
 'Egypt',
 'Macedonia',
 'Nicaragua',
 'Liberia',
 'New Zealand',
 'Ivory Coast',
 'Guinea',
 'Denmark',
 'Niger',
 'Saint Kitts and Nevis',
 'Azerbaijan',
 'Chile',
 'Cuba',
 'Lithuania',
 'Samoa',
 'Saudi Arabia',
 'Kazakhstan',
 'Kosovo',
 'Botswana',
 'Guinea-Bissau',
 'Chad',
 'Montenegro',
 'Cameroon',
 'Gabon',
 'Costa Rica',
 'Palau',
 'Djibouti',
 'Bhutan',
 'Tajikistan',
 'Western Sahara',
 'French Guiana',
 'Burkina Faso',
 'Laos',
 'Angola',
 'Sri Lanka',
 'Moldova',
 'Cyprus',
 'Guam',
 'Malawi',
 'Mali',
 'South Sudan',
 'Kiribati',
 'Martinique',
 'Lebanon',
 'Oman',
 'Turkmenistan',
 'Somalia',
 'Swaziland',
 'Mauritius',
 'Guadeloupe',
 'Timor Leste',
 'Bangladesh',
 'Greenland',
 'Tonga',
 'Maldives',
 'Guernsey',
 'Bonaire',
 'Taiwan',
 'French Polynesia',
 'Grenada',
 'Togo',
 'Jamaica',
 'Jordan',
 'Faroe Islands',
 'Brunei',
 'Qatar',
 'Vanuatu',
 'Nauru',
 'Belize',
 'Andorra',
 'Northern Mariana Islands',
 'Tokelau Islands',
 'Iceland',
 'Zambia',
 'Barbados',
 'Comoros',
 'Rwanda',
 'Isle of Man',
 'New Caledonia',
 'Åland Islands',
 'Saint Lucia',
 'Reunion',
 'Mayotte',
 'Cayman Islands',
 'Lesotho',
 'Eritrea',
 'São Tomé and Príncipe',
 'Guyana',
 'American Samoa',
 'Wallis and Futuna',
 'Kuwait',
 'Hong Kong',
 'Seychelles',
 'Saint Vincent and the Grenadines',
 'Bahrain',
 'Burundi',
 'Fiji',
 'Montserrat',
 'Trinidad and Tobago',
 'Tuvalu',
 'Marshall Islands',
 'Liechtenstein',
 'Anguilla',
 'South Georgia and the South Sandwich Islands',
 'Aruba',
 'Monaco',
 'Vatican City State',
 'Suriname',
 'Antigua and Barbuda',
 'Sint Maarten',
 'Pitcairn Islands',
 'Saint-Pierre and Miquelon',
 'Macao',
 'Saint Helena',
 'Niue',
 'US Virgin Islands',
 'Curaçao',
 'Singapore',
 'Gibraltar',
 'Solomon Islands',
 'Christmas Island',
 'French Southern Territories',
 'Svalbard',
 'British Virgin Islands',
 'Jersey',
 'Bermuda',
 'Saint Barthélemy',
 'Cook Islands',
 'Antarctica',
 'Coconut Islands',
 'Turks and Caicos']

# %%
swe_countries_2
# Out:
# ['Tyskland',
#  'Saint-Pierre och Miquelon',
#  'Tchad',
#  'Centralafrikanska republiken',
#  'Schweiz',
#  'Dominikanska republiken',
#  'Ecuador',
#  'Saint Kitts och Nevis',
#  'Djibouti',
#  'Anguilla',
#  'Gibraltar',
#  'Macao',
#  'Sierra Leone',
#  'Antarktis',
#  'Palestina',
#  'Sydgeorgien och Sydsandwichöarna',
#  'Norge',
#  'Kina',
#  'Andorra',
#  'Singapore',
#  'Burkina Faso',
#  'Estland',
#  'Tuvalu',
#  'Nederländerna',
#  'Sydsudan',
#  'Kamerun',
#  'Nordkorea',
#  'Swaziland',
#  'Pitcairnöarna',
#  'Jersey',
#  'Lettland',
#  'Monaco',
#  'Tadzjikistan',
#  'Marshallöarna',
#  'Rumänien',
#  'Grekland',
#  'Afghanistan',
#  'Japan',
#  'Bosnien och Hercegovina',
#  'Mexiko',
#  'Guam',
#  'Brittiska Jungfruöarna',
#  'Tanzania',
#  'Gabon',
#  'Nya Zeeland',
#  'Nauru',
#  'Iran',
#  'Uganda',
#  'Moldavien',
#  'Bahrain',
#  'Guernsey',
#  'Grönland',
#  'Lesotho',
#  'Kiribati',
#  'Kosovo',
#  'Timor Leste',
#  'Italien',
#  'Vietnam',
#  'Malawi',
#  'Serbien',
#  'Guadeloupe',
#  'Benin',
#  'Israel',
#  'Frankrike',
#  'Réunion',
#  'Bermuda',
#  'Indien',
#  'Antigua och Barbuda',
#  'Sri Lanka',
#  'Bonaire',
#  'Jordanien',
#  'Island',
#  'Colombia',
#  'Moçambique',
#  'Makedonien',
#  'Julön',
#  'Brasilien',
#  'Madagaskar',
#  'Oman',
#  'São Tomé och Príncipe',
#  'Kazakstan',
#  'Amerikanska Jungfruöarna',
#  'Brunei',
#  'Storbritannien',
#  'Kambodja',
#  'Marocko',
#  'Guinea',
#  'Syrien',
#  'Gambia',
#  'Republiken Kongo',
#  'Färöarna',
#  'Etiopien',
#  'Mayotte',
#  'Demokratiska Republiken Kongo',
#  'Malta',
#  'Turkmenistan',
#  'Indonesien',
#  'Wallis och Futuna',
#  'Finland',
#  'Costa Rica',
#  'Franska södra territorier',
#  'Saint Barthélemy',
#  'Västsahara',
#  'Bahamas',
#  'Kenya',
#  'Tokelauöarna',
#  'Luxemburg',
#  'Jemen',
#  'Peru',
#  'Surinam',
#  'Irland',
#  'Irak',
#  'Slovenien',
#  'Georgien',
#  'San Marino',
#  'Eritrea',
#  'Hong Kong',
#  'USA',
#  'Slovakien',
#  'Ukraina',
#  'Azerbajdzjan',
#  'Saudiarabien',
#  'Nya Kaledonien',
#  'Saint Lucia',
#  'Fiji',
#  'Isle of Man',
#  'Uruguay',
#  'Dominica',
#  'Bangladesh',
#  'Burundi',
#  'Rwanda',
#  'Sydafrika',
#  'Somalia',
#  'Kroatien',
#  'Kuba',
#  'Libyen',
#  'Litauen',
#  'Danmark',
#  'Mali',
#  'Polen',
#  'Tunisien',
#  'Österrike',
#  'Elfenbenskusten',
#  'Saint Vincent och Grenadinerna',
#  'Paraguay',
#  'Guinea-Bissau',
#  'Turks och Caicosöarna',
#  'Nordmarianerna',
#  'Chile',
#  'Nepal',
#  'Amerikanska Samoa',
#  'Australien',
#  'Jamaica',
#  'Franska Polynesien',
#  'Botswana',
#  'Martinique',
#  'Barbados',
#  'Samoa',
#  'Trinidad och Tobago',
#  'Förenade Arabemiraten',
#  'Kirgizistan',
#  'Svalbard',
#  'Uzbekistan',
#  'Sankt Helena',
#  'Niue',
#  'Laos',
#  'Guyana',
#  'Sydkorea',
#  'Ghana',
#  'Albanien',
#  'Myanmar',
#  'Sudan',
#  'Vatikanstaten',
#  'Salomonöarna',
#  'Cooköarna',
#  'Kanada',
#  'Kap Verde',
#  'Montenegro',
#  'Cypern',
#  'Taiwan',
#  'Qatar',
#  'Tjeckien',
#  'Vitryssland',
#  'Caymanöarna',
#  'Komorerna',
#  'Kuwait',
#  'Curaçao',
#  'Portugal',
#  'Tonga',
#  'Mikronesien',
#  'Thailand',
#  'Libanon',
#  'Kokosöarna',
#  'Spanien',
#  'Liechtenstein',
#  'Åland Islands',
#  'Ryssland',
#  'Bhutan',
#  'Maldiverna',
#  'Zambia',
#  'Mauretanien',
#  'Filippinerna',
#  'Angola',
#  'Mauritius',
#  'Grenada',
#  'Vanuatu',
#  'Saint Martin',
#  'Mongoliet',
#  'Nicaragua',
#  'Palau',
#  'Sint Maarten',
#  'Argentina',
#  'Ungern',
#  'Algeriet',
#  'Ekvatorialguinea',
#  'Venezuela',
#  'Pakistan',
#  'Puerto Rico',
#  'Aruba',
#  'Montserrat',
#  'Niger',
#  'Franska Guyana',
#  'Malaysia',
#  'Bulgarien',
#  'Egypten',
#  'Bolivia',
#  'Liberia',
#  'Belize',
#  'Seychellerna',
#  'Belgien',
#  'Haiti',
#  'Armenien',
#  'Guatemala',
#  'Nigeria',
#  'Panama',
#  'El Salvador',
#  'Zimbabwe',
#  'Senegal',
#  'Togo',
#  'Honduras',
#  'Papua Nya Guinea',
#  'Turkiet']

# %%
trans_countries_2 = ['Germany',
 'Saint-Pierre and Miquelon',
 'Chad',
 'Central African Republic',
 'Switzerland',
 'Dominican Republic',
 'Ecuador',
 'Saint Kitts and Nevis',
 'Djibouti',
 'Anguilla',
 'Gibraltar',
 'Macao',
 'Sierra Leone',
 'Antarctica',
 'Palestine',
 'South Georgia and the South Sandwich Islands',
 'Norway',
 'China',
 'Andorra',
 'Singapore',
 'Burkina Faso',
 'Estonia',
 'Tuvalu',
 'Netherlands',
 'South Sudan',
 'Cameroon',
 'North Korea',
 'Swaziland',
 'Pitcairn Islands',
 'Jersey',
 'Latvia',
 'Monaco',
 'Tajikistan',
 'Marshall Islands',
 'Romania',
 'Greece',
 'Afghanistan',
 'Japanese',
 'Bosnia and Herzegovina',
 'Mexico',
 'Guam',
 'British Virgin Islands',
 'Tanzania',
 'Gabon',
 'New Zealand',
 'Nauru',
 'Iran',
 'Uganda',
 'Moldova',
 'Bahrain',
 'Guernsey',
 'Greenland',
 'Lesotho',
 'Kiribati',
 'Kosovo',
 'Timor Leste',
 'Italy',
 'Vietnam',
 'Malawi',
 'Serbia',
 'Guadeloupe',
 'Benin',
 'Israel',
 'France',
 'Reunion',
 'Bermuda',
 'India',
 'Antigua and Barbuda',
 'Sri Lanka',
 'Bonaire',
 'Jordan',
 'Iceland',
 'Colombia',
 'Mozambique',
 'Macedonia',
 'Christmas Island',
 'Brazil',
 'Madagascar',
 'Oman',
 'São Tomé and Príncipe',
 'Kazakhstan',
 'US Virgin Islands',
 'Brunei',
 'UK',
 'Cambodia',
 'Morocco',
 'Guinea',
 'Syria',
 'Gambia',
 'Republic of the Congo',
 'Faroe Islands',
 'Ethiopia',
 'Mayotte',
 'The Democratic Republic of Kongo',
 'Malta',
 'Turkmenistan',
 'Indonesia',
 'Wallis and Futuna',
 'Finland',
 'Costa Rica',
 'French Southern Territories',
 'Saint Barthélemy',
 'Western Sahara',
 'Bahamas',
 'Kenya',
 'Tokelau Islands',
 'Luxembourg',
 'Yemen',
 'Peru',
 'Suriname',
 'Ireland',
 'Iraq',
 'Slovenia',
 'Georgia',
 'San Marino',
 'Eritrea',
 'Hong Kong',
 'USA',
 'Slovakia',
 'Ukraine',
 'Azerbaijan',
 'Saudi Arabia',
 'New Caledonia',
 'Saint Lucia',
 'Fiji',
 'Isle of Man',
 'Uruguay',
 'Dominica',
 'Bangladesh',
 'Burundi',
 'Rwanda',
 'South Africa',
 'Somalia',
 'Croatia',
 'Cuba',
 'Libya',
 'Lithuania',
 'Denmark',
 'Mali',
 'Poland',
 'Tunisia',
 'Austria',
 'Ivory Coast',
 'Saint Vincent and the Grenadines',
 'Paraguay',
 'Guinea-Bissau',
 'Turks and Caicos Islands',
 'Northern Mariana Islands',
 'Chile',
 'Nepal',
 'American Samoa',
 'Australia',
 'Jamaica',
 'French Polynesia',
 'Botswana',
 'Martinique',
 'Barbados',
 'Samoa',
 'Trinidad and Tobago',
 'United Arab Emirates',
 'Kyrgyzstan',
 'Svalbard',
 'Uzbekistan',
 'Saint Helena',
 'Niue',
 'Laos',
 'Guyana',
 'South Korea',
 'Ghana',
 'Albania',
 'Myanmar',
 'Sudan',
 'Vatican City State',
 'Solomon Islands',
 'Cook Islands',
 'Canada',
 'Cape Verde',
 'Montenegro',
 'Cyprus',
 'Taiwan',
 'Qatar',
 'Czech Republic',
 'Belarus',
 'Cayman Islands',
 'Comoros',
 'Kuwait',
 'Curaçao',
 'Portugal',
 'Tonga',
 'Micronesia',
 'Thailand',
 'Lebanon',
 'Coconut Islands',
 'Spain',
 'Liechtenstein',
 'Åland Islands',
 'Russia',
 'Bhutan',
 'Maldives',
 'Zambia',
 'Mauritania',
 'Philippines',
 'Angola',
 'Mauritius',
 'Grenada',
 'Vanuatu',
 'Saint Martin',
 'Mongolia',
 'Nicaragua',
 'Palau',
 'Sint Maarten',
 'Argentina',
 'Hungary',
 'Algeria',
 'Equatorial Guinea',
 'Venezuela',
 'Pakistan',
 'Puerto Rico',
 'Aruba',
 'Montserrat',
 'Niger',
 'French Guiana',
 'Malaysia',
 'Bulgaria',
 'Egypt',
 'Bolivia',
 'Liberia',
 'Belize',
 'Seychelles',
 'Belgium',
 'Haiti',
 'Armenia',
 'Guatemala',
 'Nigeria',
 'Panama',
 'El Salvador',
 'Zimbabwe',
 'Senegal',
 'Togo',
 'Honduras',
 'Papua New Guinea',
 'Turkey']

# %%
#Since the translation list contains some whitespaces at both initial and last position in some
#of the country names, this function will clean the data.

#This function returns a nested list with all the country names translated to English
def cleaning_trans(translation):
    first_index = []
    eng_countries = []
    for item in translation:
        if item[0] == ' ': #if first character in the string is a whitespace
            first_index.append(item[1:]) #add the string without the first char to the new list
        else:
            first_index.append(item) #if the word doesn't start with whitespace, just add it to the list

    for item in first_index:
        if item[-1] == ' ': #if the word ends in whitespace
            eng_countries.append(item[:-1]) #add the word without the last char to the final list
        else:
            eng_countries.append(item) #if the word doesn't have a whitespace at the end, just add the word to the list
    
    return eng_countries

# %%
eng_countries_1 = cleaning_trans(trans_countries_1)
eng_countries_2 = cleaning_trans(trans_countries_2)

# %%
#Making a (literal) dictionary with Swedish country names as keys and their English translation as values:

def swe_eng_dict(eng_countries, swe_countries):
    replace_eng = []
    replace_swe = []

    for item in eng_countries:
        if item not in swe_countries:
            replace_eng.append(item)
    for item in swe_countries:
        if item not in eng_countries:
            replace_swe.append(item)

    #Si un país en inglés no está en la lista sueca, significa que el nombre en sueco es distinto.
    #Si un país en inglés está en la lista sueca, significa que el nombre del país es igual en inglés y en sueco.
    #Ex: Bahamas
    
    #We will use zip() and dict() to make a dictionary from the two lists above (replace_swe and replace_eng)
    #since the elements follow the same order in both list. The dict will have the Swedish names as keys and the
    #English translation as the values. This way, when we call for the key, we will get the value.

    combo = zip(replace_swe, replace_eng)
    trans_dict = dict(combo)
    
    return trans_dict

# %%
dictionary_1 = swe_eng_dict(eng_countries_1, swe_countries_1)
dictionary_2 = swe_eng_dict(eng_countries_2, swe_countries_2)

# %%
#UPDATE: ADDING COMMAS AND NEW LINES AT THE END OF EACH COUNTRY NAME BC OF EASIER FORMATTING IN NEXT STEPS

def final_data(filename, dictionary):

    filedata = []

    with open(filename, 'r') as read_obj:
        csv_reader = reader(read_obj)
        header = next(csv_reader)
        filedata.append(header) #adding header = ['Cities', 'Countries']

        for row in csv_reader:
            #print('row:', row)
            country = row[1] #row[1] == country name
            if country not in dictionary:#if country name isn't in the translation dictionary
                row[0] += ','
                row[1] += '\n'
                filedata.append(row) #add the line [city name, country name] to the new list
            else: #if country in dictionary:
                row[0] += ','
                trans = dictionary[country] + '\n'
                x = [row[0], trans] #x == [city name, english country name from dict(values)]
                #x = [row[0], trans_dict[country]] #x == [city name, english country name from dict(values)]
                filedata.append(x)
        
        filedata[0][0] = 'Cities,' #formatting the header
        filedata[0][1] = 'Countries\n'
    
    return filedata

# %%
data_1 = final_data(cityCountry, dictionary_1)
data_2 = final_data(_cityCountry, dictionary_2)

# %%
#Read the list of cities in Sweden:
def swedish_cities(filename, data):
    #filename = swedish cities list (cities_sweden.csv)
    #data = final_data's output
    
    #This function reads the data (list of cities in Sweden from 'cities_sweden.csv') 
    #and creates a new list where each element is represented as [Swedish city name, Sweden]. Next, each 
    #element is appended to the list we obtained from running 'final_data' with the rest of city/country names.
    
    swe_add = [] #list where we will append the list of [Swedish city name, Sweden]
    
    with open(filename, 'r') as read_obj:
            csv_reader = reader(read_obj)
            header = next(csv_reader)
            
            for row in csv_reader:
            #row variable is a list that represents a row in csv
                row[1] += ',' #we add a comma to the city name
                country = 'Sweden\n'
                swe_add.append([row[1], country])
            
    for item in swe_add:
        #print('item:', item)
        data.append(item)
        
    return data

# %%
data_update_1 = swedish_cities(cities_sweden, data_1)
data_update_2 = swedish_cities(cities_sweden, data_2)

# %%
def rewriting_file(filename, data):
    #data = output from final_data
    #the output is a nested list and we will convert it to string
    new_data = "".join([''.join([str(c) for c in lst]) for lst in data])
    
    with open(filename, 'w') as file:
        file.write(new_data)

# %%
#Rewriting 'cityCountry.csv'

rewriting_file(cityCountry, data_update_1)

# %%
#Rewriting '_cityCountry.csv'

rewriting_file(_cityCountry, data_2)
