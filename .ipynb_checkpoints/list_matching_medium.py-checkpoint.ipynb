# %%
### ATENTION: ###
#Once this notebook is fully run, the files would be rewritten as desired, that is why it should 
#only be run once, otherwise we take the risk of ending up with the wrong format in our files.

#Additionally, for the purpose of testing or simply having the original files, they will be collected 
#in the directory 'originals'.

#When testing, make sure to change the file paths:
#city_country = root + '/Pseudonymization/dataset/originals/city_country.csv'

# %%
#THIS HERE NEEDS TO BE MODIFY!
#This function would only work for the files 'city_country.csv' because is customised according to the 
#file format (three columns, etc...).

#nº1 -- city_country

# %%
import os
from csv import reader

# %%
#Current working directory: '/home/andrea/repos'
root = os. getcwd()

#Getting absolute path to the files we will be working with
city_country = root + '/Pseudonymization/dataset/city_country.csv'

cities_sweden = root + '/Pseudonymization/dataset/cities_sweden.csv'

# %%
#Getting list of countries (in Swedish) using a csv reader

def extracting_countries(filename):
    #Open file in read mode
    with open(filename, 'r') as read_obj:
        swe_countries = []
        #Pass the file object to reader() to get the reader object
        csv_reader = reader(read_obj)
        header = next(csv_reader)
        #print('header:', header)
        #Iterate over each row in the csv using reader object
        for row in csv_reader:
            if row[1] == '' and row[2] == '': #Since we can't delete the line, we'll duplicate the prev line
                row[1] += 'Chitungwiza'
                #print('row_1:', row[1])
                row[2] += 'Zimbabwe'
                #print('row_2:', row[2])
            if row[2] == '':
                row[2] += 'Namibia' #I've realized, there's a bunch of cities from Namibia, but no country name next to them
            if row[2] not in swe_countries: #row[2] == country name
                swe_countries.append(row[2])
        
    
    return swe_countries

# %%
swe_countries_1 = extracting_countries(city_country)

# %%
swe_countries_1
# Out:
# ['Andorra',
#  'United Arab Emirates',
#  'Afganistan',
#  'Antigua och Barbuda',
#  'Anguilla',
#  'Albanien',
#  'Armenia',
#  'Angola',
#  'Antarctica',
#  'Argentina',
#  'American Samoa',
#  'Austria',
#  'Australien',
#  'Aruba',
#  'Aland Islands',
#  'Azerbajdzjan',
#  'Bosnien och Hercegovina',
#  'Barbados',
#  'Bangladesh',
#  'Belgien',
#  'Burkina Faso',
#  'Bulgarien',
#  'Bahrain',
#  'Burundi',
#  'Benin',
#  'Saint Barthelemy',
#  'Bermuda',
#  'Brunei',
#  'Bolivia',
#  'Bonaire, Saint Eustatius and Saba ',
#  'Brasilien',
#  'Bahamas',
#  'Bhutan',
#  'Botswana',
#  'Vitryssland',
#  'Belize',
#  'Kanada',
#  'Cocos Islands',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Republic of the Congo',
#  'Schweiz',
#  'Elfenbenskusten',
#  'Cook Islands',
#  'Chile',
#  'Kamerun',
#  'Kina',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Cape Verde',
#  'Curacao',
#  'Christmas Island',
#  'Cypern',
#  'Czechia',
#  'Tyskland',
#  'Djibouti',
#  'Danmark',
#  'Dominica',
#  'Dominican Republic',
#  'Algeriet',
#  'Ecuador',
#  'Estland',
#  'Egypten',
#  'Western Sahara',
#  'Eritrea',
#  'Spanien',
#  'Etiopien',
#  'Finland',
#  'Fiji',
#  'Falkland Islands',
#  'Micronesia',
#  'Faroe Islands',
#  'Frankrike',
#  'Gabon',
#  'United Kingdom',
#  'Grenada',
#  'Georgien',
#  'French Guiana',
#  'Guernsey',
#  'Ghana',
#  'Gibraltar',
#  'Greenland',
#  'Gambia',
#  'Guinea',
#  'Guadeloupe',
#  'Equatorial Guinea',
#  'Grekland',
#  'South Georgia and the South Sandwich Islands',
#  'Guatemala',
#  'Guam',
#  'Guinea-Bissau',
#  'Guyana',
#  'Hong Kong',
#  'Honduras',
#  'Kroatien',
#  'Haiti',
#  'Ungern',
#  'Indonesien',
#  'Irland',
#  'Israel',
#  'Isle of Man',
#  'Indien',
#  'Irak',
#  'Iran',
#  'Island',
#  'Italien',
#  'Jersey',
#  'Jamaica',
#  'Jordan',
#  'Japan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Kambodja',
#  'Kiribati',
#  'Comoros',
#  'Saint Kitts and Nevis',
#  'North Korea',
#  'Sydkorea',
#  'Kuwait',
#  'Cayman Islands',
#  'Kazakstan',
#  'Laos',
#  'Libanon',
#  'Saint Lucia',
#  'Liechtenstein',
#  'Sri Lanka',
#  'Liberia',
#  'Lesotho',
#  'Litauen',
#  'Luxemburg',
#  'Lettland',
#  'Libyen',
#  'Morocko',
#  'Monaco',
#  'Moldavien',
#  'Montenegro',
#  'Saint Martin',
#  'Madagaskar',
#  'Marshall Islands',
#  'Makedonien',
#  'Mali',
#  'Myanmar',
#  'Mongoliet',
#  'Macao',
#  'Northern Mariana Islands',
#  'Martinique',
#  'Mauritania',
#  'Montserrat',
#  'Malta',
#  'Mauritius',
#  'Maldiverna',
#  'Malawi',
#  'Mexiko',
#  'Malaysia',
#  'Moçambique',
#  'Namibia',
#  'New Caledonia',
#  'Niger',
#  'Norfolk Island',
#  'Nigeria',
#  'Nicaragua',
#  'Nederländerna',
#  'Norge',
#  'Nepal',
#  'Nauru',
#  'Niue',
#  'Nya Zeeland',
#  'Oman',
#  'Panama',
#  'Peru',
#  'French Polynesia',
#  'Papua New Guinea',
#  'Filippinerna',
#  'Pakistan',
#  'Polen',
#  'Saint Pierre and Miquelon',
#  'Pitcairn',
#  'Puerto Rico',
#  'Palestinian Territory',
#  'Portugal',
#  'Palau',
#  'Paraguay',
#  'Qatar',
#  'Reunion',
#  'Rumänien',
#  'Serbien',
#  'Ryssland',
#  'Rwanda',
#  'Saudiarabien',
#  'Solomon Islands',
#  'Seychelles',
#  'Sudan',
#  'Singapore',
#  'Saint Helena',
#  'Slovenien',
#  'Svalbard and Jan Mayen',
#  'Slovakien',
#  'Sierra Leone',
#  'San Marino',
#  'Senegal',
#  'Somalia',
#  'Surinam',
#  'South Sudan',
#  'Sao Tome and Principe',
#  'El Salvador',
#  'Sint Maarten',
#  'Syria',
#  'Swaziland',
#  'Turks and Caicos Islands',
#  'Tchad',
#  'French Southern Territories',
#  'Togo',
#  'Thailand',
#  'Tajikistan',
#  'Tokelau',
#  'Timor Leste',
#  'Turkmenistan',
#  'Tunisien',
#  'Tonga',
#  'Turkiet',
#  'Trinidad and Tobago',
#  'Tuvalu',
#  'Taiwan',
#  'Tanzania',
#  'Ukraina',
#  'Uganda',
#  'USA',
#  'Uruguay',
#  'Uzbekistan',
#  'Vatican',
#  'Saint Vincent and the Grenadines',
#  'Venezuela',
#  'British Virgin Islands',
#  'U.S. Virgin Islands',
#  'Vietnam',
#  'Vanuatu',
#  'Wallis and Futuna',
#  'Samoa',
#  'Kosovo',
#  'Yemen',
#  'Mayotte',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe']

# %%
trans_countries_1 = ['Andorra',
 'United Arab Emirates',
 'Afghanistan',
 'Antigua and Barbuda',
 'Anguilla',
 'Albania',
 'Armenia',
 'Angola',
 'Antarctica',
 'Argentina',
 'American Samoa',
 'Austria',
 'Australia',
 'Aruba',
 'Aland Islands',
 'Azerbaijan',
 'Bosnia and Herzegovina',
 'Barbados',
 'Bangladesh',
 'Belgium',
 'Burkina Faso',
 'Bulgaria',
 'Bahrain',
 'Burundi',
 'Benin',
 'Saint Barthelemy',
 'Bermuda',
 'Brunei',
 'Bolivia',
 'Bonaire, Saint Eustatius and Saba',
 'Brazil',
 'Bahamas',
 'Bhutan',
 'Botswana',
 'Belarus',
 'Belize',
 'Canada',
 'Cocos Islands',
 'Democratic Republic of the Congo',
 'Central African Republic',
 'Republic of the Congo',
 'Switzerland',
 'Ivory Coast',
 'Cook Islands',
 'Chile',
 'Cameroon',
 'China',
 'Colombia',
 'Costa Rica',
 'Cuba',
 'Cape Verde',
 'Curacao',
 'Christmas Island',
 'Cyprus',
 'Czechia',
 'Germany',
 'Djibouti',
 'Denmark',
 'Dominica',
 'Dominican Republic',
 'Algeria',
 'Ecuador',
 'Estonia',
 'Egypt',
 'Western Sahara',
 'Eritrea',
 'Spain',
 'Ethiopia',
 'Finland',
 'Fiji',
 'Falkland Islands',
 'Micronesia',
 'Faroe Islands',
 'France',
 'Gabon',
 'United Kingdom',
 'Grenada',
 'Georgia',
 'French Guiana',
 'Guernsey',
 'Ghana',
 'Gibraltar',
 'Greenland',
 'Gambia',
 'Guinea',
 'Guadeloupe',
 'Equatorial Guinea',
 'Greece',
 'South Georgia and the South Sandwich Islands',
 'Guatemala',
 'Guam',
 'Guinea-Bissau',
 'Guyana',
 'Hong Kong',
 'Honduras',
 'Croatia',
 'Haiti',
 'Hungary',
 'Indonesia',
 'Ireland',
 'Israel',
 'Isle of Man',
 'India',
 'Iraq',
 'Iran',
 'Iceland',
 'Italy',
 'Jersey',
 'Jamaica',
 'Jordan',
 'Japanese',
 'Kenya',
 'Kyrgyzstan',
 'Cambodia',
 'Kiribati',
 'Comoros',
 'Saint Kitts and Nevis',
 'North Korea',
 'South Korea',
 'Kuwait',
 'Cayman Islands',
 'Kazakhstan',
 'Laos',
 'Lebanon',
 'Saint Lucia',
 'Liechtenstein',
 'Sri Lanka',
 'Liberia',
 'Lesotho',
 'Lithuania',
 'Luxembourg',
 'Latvia',
 'Libya',
 'Morocco',
 'Monaco',
 'Moldova',
 'Montenegro',
 'Saint Martin',
 'Madagascar',
 'Marshall Islands',
 'Macedonia',
 'Mali',
 'Myanmar',
 'Mongolia',
 'Macao',
 'Northern Mariana Islands',
 'Martinique',
 'Mauritania',
 'Montserrat',
 'Malta',
 'Mauritius',
 'Maldives',
 'Malawi',
 'Mexico',
 'Malaysia',
 'Mozambique',
 'Namibia',
 'New Caledonia',
 'Niger',
 'Norfolk Island',
 'Nigeria',
 'Nicaragua',
 'Netherlands',
 'Norway',
 'Nepal',
 'Nauru',
 'Niue',
 'New Zealand',
 'Oman',
 'Panama',
 'Peru',
 'French Polynesia',
 'Papua New Guinea',
 'Philippines',
 'Pakistan',
 'Poland',
 'Saint Pierre and Miquelon',
 'Pitcairn',
 'Puerto Rico',
 'Palestinian Territory',
 'Portugal',
 'Palau',
 'Paraguay',
 'Qatar',
 'Reunion',
 'Romania',
 'Serbia',
 'Russia',
 'Rwanda',
 'Saudi Arabia',
 'Solomon Islands',
 'Seychelles',
 'Sudan',
 'Singapore',
 'Saint Helena',
 'Slovenia',
 'Svalbard and Jan Mayen',
 'Slovakia',
 'Sierra Leone',
 'San Marino',
 'Senegal',
 'Somalia',
 'Suriname',
 'South Sudan',
 'Sao Tome and Principe',
 'El Salvador',
 'Sint Maarten',
 'Syria',
 'Swaziland',
 'Turks and Caicos Islands',
 'Chad',
 'French Southern Territories',
 'Togo',
 'Thailand',
 'Tajikistan',
 'Tokelau',
 'Timor Leste',
 'Turkmenistan',
 'Tunisia',
 'Tonga',
 'Turkey',
 'Trinidad and Tobago',
 'Tuvalu',
 'Taiwan',
 'Tanzania',
 'Ukraine',
 'Uganda',
 'USA',
 'Uruguay',
 'Uzbekistan',
 'Vatican',
 'Saint Vincent and the Grenadines',
 'Venezuela',
 'British Virgin Islands',
 'U.S. Virgin Islands',
 'Vietnam',
 'Vanuatu',
 'Wallis and Futuna',
 'Samoa',
 'Kosovo',
 'Yemen',
 'Mayotte',
 'South Africa',
 'Zambia',
 'Zimbabwe']

# %%
#Since the translation list contains some whitespaces at both initial and last position in some
#of the country names, this function will clean the data.

#This function returns a nested list with all the country names translated to English
def cleaning_trans(translation):
    first_index = []
    eng_countries = []
    for item in translation:
        #print('item:', item)
        if item[0] == ' ': #if first character in the string is a whitespace
            first_index.append(item[1:]) #add the string without the first char to the new list
        else:
            first_index.append(item) #if the word doesn't start with whitespace, just add it to the list

    for item in first_index:
        if item[-1] == ' ': #if the word ends in whitespace
            eng_countries.append(item[:-1]) #add the word without the last char to the final list
        else:
            eng_countries.append(item) #if the word doesn't have a whitespace at the end, just add the word to the list
    
    return eng_countries

# %%
#List of all translated names of countries in 'city_country.csv'
eng_countries_1 = cleaning_trans(trans_countries_1)

# %%
eng_countries_1
# Out:
# ['Andorra',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Antigua and Barbuda',
#  'Anguilla',
#  'Albania',
#  'Armenia',
#  'Angola',
#  'Antarctica',
#  'Argentina',
#  'American Samoa',
#  'Austria',
#  'Australia',
#  'Aruba',
#  'Aland Islands',
#  'Azerbaijan',
#  'Bosnia and Herzegovina',
#  'Barbados',
#  'Bangladesh',
#  'Belgium',
#  'Burkina Faso',
#  'Bulgaria',
#  'Bahrain',
#  'Burundi',
#  'Benin',
#  'Saint Barthelemy',
#  'Bermuda',
#  'Brunei',
#  'Bolivia',
#  'Bonaire, Saint Eustatius and Saba',
#  'Brazil',
#  'Bahamas',
#  'Bhutan',
#  'Botswana',
#  'Belarus',
#  'Belize',
#  'Canada',
#  'Cocos Islands',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Republic of the Congo',
#  'Switzerland',
#  'Ivory Coast',
#  'Cook Islands',
#  'Chile',
#  'Cameroon',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Cape Verde',
#  'Curacao',
#  'Christmas Island',
#  'Cyprus',
#  'Czechia',
#  'Germany',
#  'Djibouti',
#  'Denmark',
#  'Dominica',
#  'Dominican Republic',
#  'Algeria',
#  'Ecuador',
#  'Estonia',
#  'Egypt',
#  'Western Sahara',
#  'Eritrea',
#  'Spain',
#  'Ethiopia',
#  'Finland',
#  'Fiji',
#  'Falkland Islands',
#  'Micronesia',
#  'Faroe Islands',
#  'France',
#  'Gabon',
#  'United Kingdom',
#  'Grenada',
#  'Georgia',
#  'French Guiana',
#  'Guernsey',
#  'Ghana',
#  'Gibraltar',
#  'Greenland',
#  'Gambia',
#  'Guinea',
#  'Guadeloupe',
#  'Equatorial Guinea',
#  'Greece',
#  'South Georgia and the South Sandwich Islands',
#  'Guatemala',
#  'Guam',
#  'Guinea-Bissau',
#  'Guyana',
#  'Hong Kong',
#  'Honduras',
#  'Croatia',
#  'Haiti',
#  'Hungary',
#  'Indonesia',
#  'Ireland',
#  'Israel',
#  'Isle of Man',
#  'India',
#  'Iraq',
#  'Iran',
#  'Iceland',
#  'Italy',
#  'Jersey',
#  'Jamaica',
#  'Jordan',
#  'Japanese',
#  'Kenya',
#  'Kyrgyzstan',
#  'Cambodia',
#  'Kiribati',
#  'Comoros',
#  'Saint Kitts and Nevis',
#  'North Korea',
#  'South Korea',
#  'Kuwait',
#  'Cayman Islands',
#  'Kazakhstan',
#  'Laos',
#  'Lebanon',
#  'Saint Lucia',
#  'Liechtenstein',
#  'Sri Lanka',
#  'Liberia',
#  'Lesotho',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Libya',
#  'Morocco',
#  'Monaco',
#  'Moldova',
#  'Montenegro',
#  'Saint Martin',
#  'Madagascar',
#  'Marshall Islands',
#  'Macedonia',
#  'Mali',
#  'Myanmar',
#  'Mongolia',
#  'Macao',
#  'Northern Mariana Islands',
#  'Martinique',
#  'Mauritania',
#  'Montserrat',
#  'Malta',
#  'Mauritius',
#  'Maldives',
#  'Malawi',
#  'Mexico',
#  'Malaysia',
#  'Mozambique',
#  'Namibia',
#  'New Caledonia',
#  'Niger',
#  'Norfolk Island',
#  'Nigeria',
#  'Nicaragua',
#  'Netherlands',
#  'Norway',
#  'Nepal',
#  'Nauru',
#  'Niue',
#  'New Zealand',
#  'Oman',
#  'Panama',
#  'Peru',
#  'French Polynesia',
#  'Papua New Guinea',
#  'Philippines',
#  'Pakistan',
#  'Poland',
#  'Saint Pierre and Miquelon',
#  'Pitcairn',
#  'Puerto Rico',
#  'Palestinian Territory',
#  'Portugal',
#  'Palau',
#  'Paraguay',
#  'Qatar',
#  'Reunion',
#  'Romania',
#  'Serbia',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Solomon Islands',
#  'Seychelles',
#  'Sudan',
#  'Singapore',
#  'Saint Helena',
#  'Slovenia',
#  'Svalbard and Jan Mayen',
#  'Slovakia',
#  'Sierra Leone',
#  'San Marino',
#  'Senegal',
#  'Somalia',
#  'Suriname',
#  'South Sudan',
#  'Sao Tome and Principe',
#  'El Salvador',
#  'Sint Maarten',
#  'Syria',
#  'Swaziland',
#  'Turks and Caicos Islands',
#  'Chad',
#  'French Southern Territories',
#  'Togo',
#  'Thailand',
#  'Tajikistan',
#  'Tokelau',
#  'Timor Leste',
#  'Turkmenistan',
#  'Tunisia',
#  'Tonga',
#  'Turkey',
#  'Trinidad and Tobago',
#  'Tuvalu',
#  'Taiwan',
#  'Tanzania',
#  'Ukraine',
#  'Uganda',
#  'USA',
#  'Uruguay',
#  'Uzbekistan',
#  'Vatican',
#  'Saint Vincent and the Grenadines',
#  'Venezuela',
#  'British Virgin Islands',
#  'U.S. Virgin Islands',
#  'Vietnam',
#  'Vanuatu',
#  'Wallis and Futuna',
#  'Samoa',
#  'Kosovo',
#  'Yemen',
#  'Mayotte',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe']

# %%
#Making a (literal) dictionary with Swedish country names as keys and their English translation as values:

def swe_eng_dict(eng_countries, swe_countries):
    replace_eng = []
    replace_swe = []

    for item in eng_countries:
        if item not in swe_countries:
            replace_eng.append(item)
    for item in swe_countries:
        if item not in eng_countries:
            replace_swe.append(item)

    #Si un país en inglés no está en la lista sueca, significa que el nombre en sueco es distinto.
    #Si un país en inglés está en la lista sueca, significa que el nombre del país es igual en inglés y en sueco.
    #Ex: Bahamas
    
    #We will use zip() and dict() to make a dictionary from the two lists above (replace_swe and replace_eng)
    #since the elements follow the same order in both list. The dict will have the Swedish names as keys and the
    #English translation as the values. This way, when we call for the key, we will get the value.

    combo = zip(replace_swe, replace_eng)
    trans_dict = dict(combo)
    
    return trans_dict

# %%
dictionary_1 = swe_eng_dict(eng_countries_1, swe_countries_1)

# %%
dictionary_1
# Out:
# {'Afganistan': 'Afghanistan',
#  'Antigua och Barbuda': 'Antigua and Barbuda',
#  'Albanien': 'Albania',
#  'Australien': 'Australia',
#  'Azerbajdzjan': 'Azerbaijan',
#  'Bosnien och Hercegovina': 'Bosnia and Herzegovina',
#  'Belgien': 'Belgium',
#  'Bulgarien': 'Bulgaria',
#  'Bonaire, Saint Eustatius and Saba ': 'Bonaire, Saint Eustatius and Saba',
#  'Brasilien': 'Brazil',
#  'Vitryssland': 'Belarus',
#  'Kanada': 'Canada',
#  'Schweiz': 'Switzerland',
#  'Elfenbenskusten': 'Ivory Coast',
#  'Kamerun': 'Cameroon',
#  'Kina': 'China',
#  'Cypern': 'Cyprus',
#  'Tyskland': 'Germany',
#  'Danmark': 'Denmark',
#  'Algeriet': 'Algeria',
#  'Estland': 'Estonia',
#  'Egypten': 'Egypt',
#  'Spanien': 'Spain',
#  'Etiopien': 'Ethiopia',
#  'Frankrike': 'France',
#  'Georgien': 'Georgia',
#  'Grekland': 'Greece',
#  'Kroatien': 'Croatia',
#  'Ungern': 'Hungary',
#  'Indonesien': 'Indonesia',
#  'Irland': 'Ireland',
#  'Indien': 'India',
#  'Irak': 'Iraq',
#  'Island': 'Iceland',
#  'Italien': 'Italy',
#  'Japan': 'Japanese',
#  'Kambodja': 'Cambodia',
#  'Sydkorea': 'South Korea',
#  'Kazakstan': 'Kazakhstan',
#  'Libanon': 'Lebanon',
#  'Litauen': 'Lithuania',
#  'Luxemburg': 'Luxembourg',
#  'Lettland': 'Latvia',
#  'Libyen': 'Libya',
#  'Morocko': 'Morocco',
#  'Moldavien': 'Moldova',
#  'Madagaskar': 'Madagascar',
#  'Makedonien': 'Macedonia',
#  'Mongoliet': 'Mongolia',
#  'Maldiverna': 'Maldives',
#  'Mexiko': 'Mexico',
#  'Moçambique': 'Mozambique',
#  'Nederländerna': 'Netherlands',
#  'Norge': 'Norway',
#  'Nya Zeeland': 'New Zealand',
#  'Filippinerna': 'Philippines',
#  'Polen': 'Poland',
#  'Rumänien': 'Romania',
#  'Serbien': 'Serbia',
#  'Ryssland': 'Russia',
#  'Saudiarabien': 'Saudi Arabia',
#  'Slovenien': 'Slovenia',
#  'Slovakien': 'Slovakia',
#  'Surinam': 'Suriname',
#  'Tchad': 'Chad',
#  'Tunisien': 'Tunisia',
#  'Turkiet': 'Turkey',
#  'Ukraina': 'Ukraine'}

# %%
#UPDATE: ADDING COMMAS AND NEW LINES AT THE END OF EACH COUNTRY NAME BC OF EASIER FORMATTING IN NEXT STEPS

def final_data(filename, dictionary):

    filedata = []

    with open(filename, 'r') as read_obj:
        csv_reader = reader(read_obj)
        header = next(csv_reader)
        #print('header:', header)
        filedata.append(header) #adding header = ['Cities', 'Countries']

        for row in csv_reader:
            #print('row:', row)
            country = row[2] #row[2] == country name
            if country not in dictionary:#if country name isn't in the translation dictionary
                row[0] += ','
                #print('row0:', row[0])
                row[1] += ','
                #print('row1:', row[1])
                row[2] += '\n'
                #print('row2:', row[2])
                filedata.append(row) #add the line [line counter, city name, country name] to the new list
                #print('filedata_pre:', filedata[:10])
            
            else: #if country in dictionary:
                row[0] += ','
                row[1] += ','
                trans = dictionary[country] + '\n'
                x = [row[0], row[1], trans] #x == [city name, english country name from dict(values)]
                #x = [row[0], trans_dict[country]] #x == [city name, english country name from dict(values)]
                filedata.append(x)
        
        filedata[0][0] = ',' #formatting the header
        filedata[0][1] = 'Cities,'
        filedata[0][2] = 'Countries\n'
    
    return filedata[:-1] #bc the last line is just empty in the original file

# %%
data_1 = final_data(city_country, dictionary_1)

# %%
data_1
# Out:
# [[',', 'Cities,', 'Countries\n'],
#  ['0,', 'El Tarter,', 'Andorra\n'],
#  ['1,', 'Sant Julià de Lòria,', 'Andorra\n'],
#  ['2,', 'Pas de la Casa,', 'Andorra\n'],
#  ['3,', 'Ordino,', 'Andorra\n'],
#  ['4,', 'les Escaldes,', 'Andorra\n'],
#  ['5,', 'la Massana,', 'Andorra\n'],
#  ['6,', 'Encamp,', 'Andorra\n'],
#  ['7,', 'Canillo,', 'Andorra\n'],
#  ['8,', 'Arinsal,', 'Andorra\n'],
#  ['9,', 'Andorra la Vella,', 'Andorra\n'],
#  ['10,', 'Umm al Qaywayn,', 'United Arab Emirates\n'],
#  ['11,', 'Ras al-Khaimah,', 'United Arab Emirates\n'],
#  ['12,', 'Muzayri‘,', 'United Arab Emirates\n'],
#  ['13,', 'Murbaḩ,', 'United Arab Emirates\n'],
#  ['14,', 'Khawr Fakkān,', 'United Arab Emirates\n'],
#  ['15,', 'Dubai,', 'United Arab Emirates\n'],
#  ['16,', 'Dibba Al-Fujairah,', 'United Arab Emirates\n'],
#  ['17,', 'Dibba Al-Hisn,', 'United Arab Emirates\n'],
#  ['18,', 'Sharjah,', 'United Arab Emirates\n'],
#  ['19,', 'Ar Ruways,', 'United Arab Emirates\n'],
#  ['20,', 'Al Fujayrah,', 'United Arab Emirates\n'],
#  ['21,', 'Al Ain,', 'United Arab Emirates\n'],
#  ['22,', 'Ajman,', 'United Arab Emirates\n'],
#  ['23,', 'Adh Dhayd,', 'United Arab Emirates\n'],
#  ['24,', 'Abu Dhabi,', 'United Arab Emirates\n'],
#  ['25,', 'Zorkot,', 'Afghanistan\n'],
#  ['26,', 'Wulêswālī Bihsūd,', 'Afghanistan\n'],
#  ['27,', 'Kuhsān,', 'Afghanistan\n'],
#  ['28,', 'Lāsh,', 'Afghanistan\n'],
#  ['29,', 'Tukzār,', 'Afghanistan\n'],
#  ['30,', 'Mīray,', 'Afghanistan\n'],
#  ['31,', 'Āq Kupruk,', 'Afghanistan\n'],
#  ['32,', 'Zurmat,', 'Afghanistan\n'],
#  ['33,', 'Zaybāk,', 'Afghanistan\n'],
#  ['34,', 'Zīārat-e Shāh Maqşūd,', 'Afghanistan\n'],
#  ['35,', 'Zindah Jān,', 'Afghanistan\n'],
#  ['36,', 'Zarghūn Shahr,', 'Afghanistan\n'],
#  ['37,', 'Zaṟah Sharan,', 'Afghanistan\n'],
#  ['38,', 'Zaranj,', 'Afghanistan\n'],
#  ['39,', 'Zamtō Kêlay,', 'Afghanistan\n'],
#  ['40,', 'Yangī Qal‘ah,', 'Afghanistan\n'],
#  ['41,', 'Yaḩyá Khēl,', 'Afghanistan\n'],
#  ['42,', 'Wāshēr,', 'Afghanistan\n'],
#  ['43,', 'Tōrmay,', 'Afghanistan\n'],
#  ['44,', 'Tūlak,', 'Afghanistan\n'],
#  ['45,', 'Tītān,', 'Afghanistan\n'],
#  ['46,', 'Tīr Pul,', 'Afghanistan\n'],
#  ['47,', 'Taywarah,', 'Afghanistan\n'],
#  ['48,', 'Bāzār-e Tashkān,', 'Afghanistan\n'],
#  ['49,', 'Tarinkot,', 'Afghanistan\n'],
#  ['50,', 'Taloqan,', 'Afghanistan\n'],
#  ['51,', 'Tagāw-Bāy,', 'Afghanistan\n'],
#  ['52,', 'Tagāb,', 'Afghanistan\n'],
#  ['53,', 'Markaz-e Ḩukūmat-e Sulţān-e Bakwāh,', 'Afghanistan\n'],
#  ['54,', 'Spīn Bōldak,', 'Afghanistan\n'],
#  ['55,', 'Spērah,', 'Afghanistan\n'],
#  ['56,', 'Sōzmah Qal‘ah,', 'Afghanistan\n'],
#  ['57,', 'Siyāhgird,', 'Afghanistan\n'],
#  ['58,', 'Sheywah,', 'Afghanistan\n'],
#  ['59,', 'Shīnḏanḏ,', 'Afghanistan\n'],
#  ['60,', 'Shaykh Amīr Kêlay,', 'Afghanistan\n'],
#  ['61,', 'Qāshqāl,', 'Afghanistan\n'],
#  ['62,', 'Shibirghān,', 'Afghanistan\n'],
#  ['63,', 'Shwāk,', 'Afghanistan\n'],
#  ['64,', 'Shahr-e Şafā,', 'Afghanistan\n'],
#  ['65,', 'Shahrān,', 'Afghanistan\n'],
#  ['66,', 'Shahrak,', 'Afghanistan\n'],
#  ['67,', '‘Alāqahdārī Shāh Jōy,', 'Afghanistan\n'],
#  ['68,', 'Wulêswālī Sayyid Karam,', 'Afghanistan\n'],
#  ['69,', 'Markaz-e Sayyidābād,', 'Afghanistan\n'],
#  ['70,', 'Şayād,', 'Afghanistan\n'],
#  ['71,', 'Sidqābād,', 'Afghanistan\n'],
#  ['72,', 'Sāyagaz,', 'Afghanistan\n'],
#  ['73,', 'Sar-e Tayghān,', 'Afghanistan\n'],
#  ['74,', 'Sarōbī,', 'Afghanistan\n'],
#  ['75,', 'Sar Kāṉī,', 'Afghanistan\n'],
#  ['76,', 'Sarfirāz Kalā,', 'Afghanistan\n'],
#  ['77,', 'Sar-e Pul,', 'Afghanistan\n'],
#  ['78,', 'Sar Chakān,', 'Afghanistan\n'],
#  ['79,', 'Sangīn,', 'Afghanistan\n'],
#  ['80,', 'Sang-e Māshah,', 'Afghanistan\n'],
#  ['81,', 'Sang-e Chārak,', 'Afghanistan\n'],
#  ['82,', 'Sang Atesh,', 'Afghanistan\n'],
#  ['83,', 'Sangar Sarāy,', 'Afghanistan\n'],
#  ['84,', 'Aībak,', 'Afghanistan\n'],
#  ['85,', 'Rū-ye Sang,', 'Afghanistan\n'],
#  ['86,', 'Rūdbār,', 'Afghanistan\n'],
#  ['87,', 'Rustāq,', 'Afghanistan\n'],
#  ['88,', 'Rabāţ-e Sangī-ye Pā’īn,', 'Afghanistan\n'],
#  ['89,', 'Rāmak,', 'Afghanistan\n'],
#  ['90,', 'Qurghān,', 'Afghanistan\n'],
#  ['91,', 'Quchanghī,', 'Afghanistan\n'],
#  ['92,', 'Sangalak-i-Kaisar,', 'Afghanistan\n'],
#  ['93,', 'Qarqīn,', 'Afghanistan\n'],
#  ['94,', 'Qarghah’ī,', 'Afghanistan\n'],
#  ['95,', 'Qarchī Gak,', 'Afghanistan\n'],
#  ['96,', 'Qarāwul,', 'Afghanistan\n'],
#  ['97,', 'Qarah Bāgh,', 'Afghanistan\n'],
#  ['98,', 'Qarah Bāgh,', 'Afghanistan\n'],
#  ['99,', 'Qala i Naw,', 'Afghanistan\n'],
#  ['100,', 'Qal‘ah-ye Kūf,', 'Afghanistan\n'],
#  ['101,', 'Qal‘ah-ye Kuhnah,', 'Afghanistan\n'],
#  ['102,', 'Qal‘ah-ye Shahr,', 'Afghanistan\n'],
#  ['103,', 'Qalāt,', 'Afghanistan\n'],
#  ['104,', 'Qal‘ah-ye Shāhī,', 'Afghanistan\n'],
#  ['105,', 'Qādis,', 'Afghanistan\n'],
#  ['106,', 'Pārūn,', 'Afghanistan\n'],
#  ['107,', 'Pul-e Khumrī,', 'Afghanistan\n'],
#  ['108,', 'Pul-e ‘Alam,', 'Afghanistan\n'],
#  ['109,', 'Pasnay,', 'Afghanistan\n'],
#  ['110,', 'Pāshmūl,', 'Afghanistan\n'],
#  ['111,', 'Pasāband,', 'Afghanistan\n'],
#  ['112,', 'Panjāb,', 'Afghanistan\n'],
#  ['113,', 'Paghmān,', 'Afghanistan\n'],
#  ['114,', 'Ōmnah,', 'Afghanistan\n'],
#  ['115,', 'Qaryeh-ye Owbeh,', 'Afghanistan\n'],
#  ['116,', 'Uruzgān,', 'Afghanistan\n'],
#  ['117,', 'Urgun,', 'Afghanistan\n'],
#  ['118,', 'Nūsay,', 'Afghanistan\n'],
#  ['119,', 'Nūrgal,', 'Afghanistan\n'],
#  ['120,', 'Now Zād,', 'Afghanistan\n'],
#  ['121,', 'Nīlī,', 'Afghanistan\n'],
#  ['122,', 'Nayak,', 'Afghanistan\n'],
#  ['123,', 'Nāyak,', 'Afghanistan\n'],
#  ['124,', 'Now Dahānak,', 'Afghanistan\n'],
#  ['125,', 'Ōkak,', 'Afghanistan\n'],
#  ['126,', 'Nāṟay,', 'Afghanistan\n'],
#  ['127,', 'Narang,', 'Afghanistan\n'],
#  ['128,', 'Nīkêh,', 'Afghanistan\n'],
#  ['129,', 'Nahrīn,', 'Afghanistan\n'],
#  ['130,', 'Ḩukūmat-e Nād ‘Alī,', 'Afghanistan\n'],
#  ['131,', 'Mūsá Qal‘ah,', 'Afghanistan\n'],
#  ['132,', 'Bala Murghab,', 'Afghanistan\n'],
#  ['133,', 'Muqêr,', 'Afghanistan\n'],
#  ['134,', 'Muḩammad Āghah Wuluswālī,', 'Afghanistan\n'],
#  ['135,', 'Mīzān ‘Alāqahdārī,', 'Afghanistan\n'],
#  ['136,', 'Mīr Bachah Kōṯ,', 'Afghanistan\n'],
#  ['137,', 'Mīrān,', 'Afghanistan\n'],
#  ['138,', 'Mīrābād,', 'Afghanistan\n'],
#  ['139,', 'Maymana,', 'Afghanistan\n'],
#  ['140,', 'Maīdān Khūlah,', 'Afghanistan\n'],
#  ['141,', 'Mingajik,', 'Afghanistan\n'],
#  ['142,', 'Mehtar Lām,', 'Afghanistan\n'],
#  ['143,', 'Mazār-e Sharīf,', 'Afghanistan\n'],
#  ['144,', 'Māymay,', 'Afghanistan\n'],
#  ['145,', 'Mutā Khān,', 'Afghanistan\n'],
#  ['146,', 'Mashhad,', 'Afghanistan\n'],
#  ['147,', 'Mardīān,', 'Afghanistan\n'],
#  ['148,', 'Mandōl,', 'Afghanistan\n'],
#  ['149,', 'Māmā Khēl,', 'Afghanistan\n'],
#  ['150,', 'Lashkar Gāh,', 'Afghanistan\n'],
#  ['151,', 'Lāsh-e Juwayn,', 'Afghanistan\n'],
#  ['152,', 'Larkird,', 'Afghanistan\n'],
#  ['153,', 'La‘l,', 'Afghanistan\n'],
#  ['154,', 'Kushk,', 'Afghanistan\n'],
#  ['155,', 'Kōṯowāl,', 'Afghanistan\n'],
#  ['156,', 'Kushk-e Kuhnah,', 'Afghanistan\n'],
#  ['157,', 'Kuran wa Munjan,', 'Afghanistan\n'],
#  ['158,', 'Kunduz,', 'Afghanistan\n'],
#  ['159,', 'Khōshī,', 'Afghanistan\n'],
#  ['160,', 'Khōshāmand,', 'Afghanistan\n'],
#  ['161,', 'Khwājah Ghār,', 'Afghanistan\n'],
#  ['162,', 'Khwājah Dū Kōh,', 'Afghanistan\n'],
#  ['163,', 'Deh Khwāhān,', 'Afghanistan\n'],
#  ['164,', 'Khulbisāt,', 'Afghanistan\n'],
#  ['165,', 'Khūgyāṉī,', 'Afghanistan\n'],
#  ['166,', 'Khōst,', 'Afghanistan\n'],
#  ['167,', 'Khulm,', 'Afghanistan\n'],
#  ['168,', 'Khudāydād Khēl,', 'Afghanistan\n'],
#  ['169,', 'Khinjān,', 'Afghanistan\n'],
#  ['170,', 'Khinj,', 'Afghanistan\n'],
#  ['171,', 'Khāsh,', 'Afghanistan\n'],
#  ['172,', 'Khān Neshīn,', 'Afghanistan\n'],
#  ['173,', 'Khānaqāh,', 'Afghanistan\n'],
#  ['174,', 'Chahār Bāgh,', 'Afghanistan\n'],
#  ['175,', 'Khandūd,', 'Afghanistan\n'],
#  ['176,', 'Khānaqāh,', 'Afghanistan\n'],
#  ['177,', 'Khanabad,', 'Afghanistan\n'],
#  ['178,', 'Khamyāb,', 'Afghanistan\n'],
#  ['179,', 'Khākirān,', 'Afghanistan\n'],
#  ['180,', 'Kaz̲h̲ah,', 'Afghanistan\n'],
#  ['181,', 'Kishk-e Nakhūd,', 'Afghanistan\n'],
#  ['182,', 'Karukh,', 'Afghanistan\n'],
#  ['183,', 'Kanḏay,', 'Afghanistan\n'],
#  ['184,', 'Kandahār,', 'Afghanistan\n'],
#  ['185,', 'Kalān Deh,', 'Afghanistan\n'],
#  ['186,', 'Kalakān,', 'Afghanistan\n'],
#  ['187,', 'Kalafgān,', 'Afghanistan\n'],
#  ['188,', 'Kajrān,', 'Afghanistan\n'],
#  ['189,', 'Kai,', 'Afghanistan\n'],
#  ['190,', 'Kabul,', 'Afghanistan\n'],
#  ['191,', 'Jurm,', 'Afghanistan\n'],
#  ['192,', 'Jawand,', 'Afghanistan\n'],
#  ['193,', 'Jānī Khēl,', 'Afghanistan\n'],
#  ['194,', 'Jalrēz,', 'Afghanistan\n'],
#  ['195,', 'Jalālābād,', 'Afghanistan\n'],
#  ['196,', 'Jabal os Saraj,', 'Afghanistan\n'],
#  ['197,', 'Ḩukūmat-e Shīnkaī,', 'Afghanistan\n'],
#  ['198,', 'Herāt,', 'Afghanistan\n'],
#  ['199,', 'Ḩājī Khēl,', 'Afghanistan\n'],
#  ['200,', 'Ḩāfiz̧ Moghul,', 'Afghanistan\n'],
#  ['201,', 'Khafizan,', 'Afghanistan\n'],
#  ['202,', 'Guz̄arah,', 'Afghanistan\n'],
#  ['203,', 'Gōshtah,', 'Afghanistan\n'],
#  ['204,', 'Gōmal Kêlay,', 'Afghanistan\n'],
#  ['205,', '‘Alāqahdārī Gēlān,', 'Afghanistan\n'],
#  ['206,', 'Ghōriyān,', 'Afghanistan\n'],
#  ['207,', 'Ghormach,', 'Afghanistan\n'],
#  ['208,', 'Ghurayd Gharamē,', 'Afghanistan\n'],
#  ['209,', 'Ghazni,', 'Afghanistan\n'],
#  ['210,', 'Gereshk,', 'Afghanistan\n'],
#  ['211,', 'Gardez,', 'Afghanistan\n'],
#  ['212,', 'Fayzabad,', 'Afghanistan\n'],
#  ['213,', 'Faīẕābād,', 'Afghanistan\n'],
#  ['214,', 'Fayẕābād,', 'Afghanistan\n'],
#  ['215,', 'Qal‘ah-ye Fārsī,', 'Afghanistan\n'],
#  ['216,', 'Farkhār,', 'Afghanistan\n'],
#  ['217,', 'Farah,', 'Afghanistan\n'],
#  ['218,', 'Istālif,', 'Afghanistan\n'],
#  ['219,', 'Kafir Qala,', 'Afghanistan\n'],
#  ['220,', 'Injīl,', 'Afghanistan\n'],
#  ['221,', 'Imām Şāḩib,', 'Afghanistan\n'],
#  ['222,', 'Dōshī,', 'Afghanistan\n'],
#  ['223,', 'Dowlatyār,', 'Afghanistan\n'],
#  ['224,', 'Dowlat Shāh,', 'Afghanistan\n'],
#  ['225,', 'Dowlatābād,', 'Afghanistan\n'],
#  ['226,', 'Dowlatābād,', 'Afghanistan\n'],
#  ['227,', 'Dū Qal‘ah,', 'Afghanistan\n'],
#  ['228,', 'Dūāb,', 'Afghanistan\n'],
#  ['229,', 'Dê Nārkhēl Kêlay,', 'Afghanistan\n'],
#  ['230,', 'Dehī,', 'Afghanistan\n'],
#  ['231,', 'Deh-e Şalāḩ,', 'Afghanistan\n'],
#  ['232,', 'Deh-e Now,', 'Afghanistan\n'],
#  ['233,', 'Dehdādī,', 'Afghanistan\n'],
#  ['234,', 'Dwah Manḏay,', 'Afghanistan\n'],
#  ['235,', 'Dasht-e Qal‘ah,', 'Afghanistan\n'],
#  ['236,', 'Dasht-e Qal‘ah,', 'Afghanistan\n'],
#  ['237,', 'Dasht-e Archī,', 'Afghanistan\n'],
#  ['238,', 'Darzāb,', 'Afghanistan\n'],
#  ['239,', 'Markaz-e Ḩukūmat-e Darwēshān,', 'Afghanistan\n'],
#  ['240,', 'Darqad,', 'Afghanistan\n'],
#  ['241,', 'Darāyim,', 'Afghanistan\n'],
#  ['242,', 'Dāngām,', 'Afghanistan\n'],
#  ['243,', 'Ḏanḏar,', 'Afghanistan\n'],
#  ['244,', 'Ḩukūmatī Dahanah-ye Ghōrī,', 'Afghanistan\n'],
#  ['245,', 'Tsowkêy,', 'Afghanistan\n'],
#  ['246,', 'Chīras,', 'Afghanistan\n'],
#  ['247,', 'Chisht-e Sharīf,', 'Afghanistan\n'],
#  ['248,', 'Chinār,', 'Afghanistan\n'],
#  ['249,', 'Chimtāl,', 'Afghanistan\n'],
#  ['250,', 'Charkh,', 'Afghanistan\n'],
#  ['251,', 'Charikar,', 'Afghanistan\n'],
#  ['252,', 'Dowr-e Rabāţ,', 'Afghanistan\n'],
#  ['253,', 'Tsapêraī,', 'Afghanistan\n'],
#  ['254,', 'Tsamkanī,', 'Afghanistan\n'],
#  ['255,', 'Chakaray,', 'Afghanistan\n'],
#  ['256,', 'Chākarān,', 'Afghanistan\n'],
#  ['257,', 'Chahār Qal‘ah,', 'Afghanistan\n'],
#  ['258,', 'Chahār Burj,', 'Afghanistan\n'],
#  ['259,', 'Chāh Āb,', 'Afghanistan\n'],
#  ['260,', 'Fayrōz Kōh,', 'Afghanistan\n'],
#  ['261,', 'Bulōlah,', 'Afghanistan\n'],
#  ['262,', 'Bal Chirāgh,', 'Afghanistan\n'],
#  ['263,', 'Bāzār-e Tālah,', 'Afghanistan\n'],
#  ['264,', 'Bāsawul,', 'Afghanistan\n'],
#  ['265,', 'Būrkah,', 'Afghanistan\n'],
#  ['266,', 'Barg-e Matāl,', 'Afghanistan\n'],
#  ['267,', 'Baraki Barak,', 'Afghanistan\n'],
#  ['268,', 'Banū,', 'Afghanistan\n'],
#  ['269,', 'Bāmyān,', 'Afghanistan\n'],
#  ['270,', 'Balkh,', 'Afghanistan\n'],
#  ['271,', 'Bahārak,', 'Afghanistan\n'],
#  ['272,', 'Bagrāmī,', 'Afghanistan\n'],
#  ['273,', 'Baghlān,', 'Afghanistan\n'],
#  ['274,', 'Ḩukūmatī Azrah,', 'Afghanistan\n'],
#  ['275,', 'Ārt Khwājah,', 'Afghanistan\n'],
#  ['276,', '‘Alāqahdārī Aṯghar,', 'Afghanistan\n'],
#  ['277,', 'Āsmār,', 'Afghanistan\n'],
#  ['278,', 'Ashkāsham,', 'Afghanistan\n'],
#  ['279,', 'Asadābād,', 'Afghanistan\n'],
#  ['280,', 'Āqchah,', 'Afghanistan\n'],
#  ['281,', 'Andkhōy,', 'Afghanistan\n'],
#  ['282,', '’Unābah,', 'Afghanistan\n'],
#  ['283,', 'Anār Darah,', 'Afghanistan\n'],
#  ['284,', 'Amānzī,', 'Afghanistan\n'],
#  ['285,', '‘Alāqahdārī-ye Almār,', 'Afghanistan\n'],
#  ['286,', '‘Alī Shēr ‘Alāqahdārī,', 'Afghanistan\n'],
#  ['287,', 'Wuluswālī ‘Alīngār,', 'Afghanistan\n'],
#  ['288,', '‘Alī Khēl,', 'Afghanistan\n'],
#  ['289,', '‘Alāqahdārī Yōsuf Khēl,', 'Afghanistan\n'],
#  ['290,', '‘Alāqahdārī Dīshū,', 'Afghanistan\n'],
#  ['291,', 'Alah Sāy,', 'Afghanistan\n'],
#  ['292,', 'Pachīr wa Āgām,', 'Afghanistan\n'],
#  ['293,', 'Afaki,', 'Afghanistan\n'],
#  ['294,', 'Adraskan,', 'Afghanistan\n'],
#  ['295,', 'Āb-e Kamarī,', 'Afghanistan\n'],
#  ['296,', 'Khadīr,', 'Afghanistan\n'],
#  ['297,', 'Ghulām ‘Alī,', 'Afghanistan\n'],
#  ['298,', 'Qarah Bāgh Bāzār,', 'Afghanistan\n'],
#  ['299,', 'Zargarān,', 'Afghanistan\n'],
#  ['300,', 'Surkh Bilandī,', 'Afghanistan\n'],
#  ['301,', 'Pul-e Sangī,', 'Afghanistan\n'],
#  ['302,', 'Langar,', 'Afghanistan\n'],
#  ['303,', 'Bāgh-e Maīdān,', 'Afghanistan\n'],
#  ['304,', 'Ibrāhīm Khān,', 'Afghanistan\n'],
#  ['305,', 'Qaranghū Tōghaī,', 'Afghanistan\n'],
#  ['306,', 'Bāzārak,', 'Afghanistan\n'],
#  ['307,', 'Shērwānī-ye Bālā,', 'Afghanistan\n'],
#  ['308,', 'Kirāmān,', 'Afghanistan\n'],
#  ['309,', '‘Alāqahdārī Saṟōbī,', 'Afghanistan\n'],
#  ['310,', 'Zerok-Alakadari,', 'Afghanistan\n'],
#  ['311,', 'Kushkak,', 'Afghanistan\n'],
#  ['312,', 'Khayr Kōṯ,', 'Afghanistan\n'],
#  ['313,', 'Chowṉêy,', 'Afghanistan\n'],
#  ['314,', 'Wuṯahpūr,', 'Afghanistan\n'],
#  ['315,', 'Karbori,', 'Afghanistan\n'],
#  ['316,', 'Sulţānpūr-e ‘Ulyā,', 'Afghanistan\n'],
#  ['317,', 'Babasakhib,', 'Afghanistan\n'],
#  ['318,', 'Chandal Bā’ī,', 'Afghanistan\n'],
#  ['319,', 'Dahan-e Jarf,', 'Afghanistan\n'],
#  ['320,', 'Maydanshakhr,', 'Afghanistan\n'],
#  ['321,', 'Dū Laīnah,', 'Afghanistan\n'],
#  ['322,', 'Qaram Qōl,', 'Afghanistan\n'],
#  ['323,', 'Pul-e Ḩişār,', 'Afghanistan\n'],
#  ['324,', 'Lab-Sar,', 'Afghanistan\n'],
#  ['325,', 'Ţāqchah Khānah,', 'Afghanistan\n'],
#  ['326,', 'March,', 'Afghanistan\n'],
#  ['327,', 'Zīrakī,', 'Afghanistan\n'],
#  ['328,', 'Aliabad,', 'Afghanistan\n'],
#  ['329,', 'Pas Pul,', 'Afghanistan\n'],
#  ['330,', 'Qal‘ah-ye Na‘īm,', 'Afghanistan\n'],
#  ['331,', 'Markaz-e Woluswalī-ye Āchīn,', 'Afghanistan\n'],
#  ['332,', 'Manogay,', 'Afghanistan\n'],
#  ['333,', 'Stêr Giyān,', 'Afghanistan\n'],
#  ['334,', 'Sharan,', 'Afghanistan\n'],
#  ['335,', 'Salām Khēl,', 'Afghanistan\n'],
#  ['336,', 'Saint John’s,', 'Antigua and Barbuda\n'],
#  ['337,', 'Potters Village,', 'Antigua and Barbuda\n'],
#  ['338,', 'Piggotts,', 'Antigua and Barbuda\n'],
#  ['339,', 'Parham,', 'Antigua and Barbuda\n'],
#  ['340,', 'Liberta,', 'Antigua and Barbuda\n'],
#  ['341,', 'Falmouth,', 'Antigua and Barbuda\n'],
#  ['342,', 'Codrington,', 'Antigua and Barbuda\n'],
#  ['343,', 'Bolands,', 'Antigua and Barbuda\n'],
#  ['344,', 'All Saints,', 'Antigua and Barbuda\n'],
#  ['345,', 'West End Village,', 'Anguilla\n'],
#  ['346,', 'The Valley,', 'Anguilla\n'],
#  ['347,', 'The Quarter,', 'Anguilla\n'],
#  ['348,', 'Farrington,', 'Anguilla\n'],
#  ['349,', 'Stoney Ground,', 'Anguilla\n'],
#  ['350,', 'South Hill Village,', 'Anguilla\n'],
#  ['351,', 'Sandy Ground Village,', 'Anguilla\n'],
#  ['352,', 'North Side,', 'Anguilla\n'],
#  ['353,', 'North Hill Village,', 'Anguilla\n'],
#  ['354,', 'Island Harbour,', 'Anguilla\n'],
#  ['355,', 'George Hill,', 'Anguilla\n'],
#  ['356,', 'East End Village,', 'Anguilla\n'],
#  ['357,', 'Blowing Point Village,', 'Anguilla\n'],
#  ['358,', 'Sandy Hill,', 'Anguilla\n'],
#  ['359,', 'Xarrë,', 'Albania\n'],
#  ['360,', 'Sarandë,', 'Albania\n'],
#  ['361,', 'Mesopotam,', 'Albania\n'],
#  ['362,', 'Markat,', 'Albania\n'],
#  ['363,', 'Livadhja,', 'Albania\n'],
#  ['364,', 'Konispol,', 'Albania\n'],
#  ['365,', 'Kakavijë,', 'Albania\n'],
#  ['366,', 'Finiq,', 'Albania\n'],
#  ['367,', 'Dhivër,', 'Albania\n'],
#  ['368,', 'Delvinë,', 'Albania\n'],
#  ['369,', 'Aliko,', 'Albania\n'],
#  ['370,', 'Buçimas,', 'Albania\n'],
#  ['371,', 'Zhepë,', 'Albania\n'],
#  ['372,', 'Zerqan,', 'Albania\n'],
#  ['373,', 'Zavalinë,', 'Albania\n'],
#  ['374,', 'Zapod,', 'Albania\n'],
#  ['375,', 'Zall-Reç,', 'Albania\n'],
#  ['376,', 'Zall-Dardhë,', 'Albania\n'],
#  ['377,', 'Xibër-Murrizë,', 'Albania\n'],
#  ['378,', 'Vreshtas,', 'Albania\n'],
#  ['379,', 'Voskopojë,', 'Albania\n'],
#  ['380,', 'Voskop,', 'Albania\n'],
#  ['381,', 'Vithkuq,', 'Albania\n'],
#  ['382,', 'Vithkuq,', 'Albania\n'],
#  ['383,', 'Vërtop,', 'Albania\n'],
#  ['384,', 'Vergo,', 'Albania\n'],
#  ['385,', 'Vendresha e Vogël,', 'Albania\n'],
#  ['386,', 'Velçan,', 'Albania\n'],
#  ['387,', 'Ujmisht,', 'Albania\n'],
#  ['388,', 'Udënisht,', 'Albania\n'],
#  ['389,', 'Tunjë,', 'Albania\n'],
#  ['390,', 'Tregan,', 'Albania\n'],
#  ['391,', 'Trebisht-Muçinë,', 'Albania\n'],
#  ['392,', 'Trebinjë,', 'Albania\n'],
#  ['393,', 'Topojan,', 'Albania\n'],
#  ['394,', 'Tomin,', 'Albania\n'],
#  ['395,', 'Tepelenë,', 'Albania\n'],
#  ['396,', 'Surroj,', 'Albania\n'],
#  ['397,', 'Sult,', 'Albania\n'],
#  ['398,', 'Sukë,', 'Albania\n'],
#  ['399,', 'Suç,', 'Albania\n'],
#  ['400,', 'Stravaj,', 'Albania\n'],
#  ['401,', 'Steblevë,', 'Albania\n'],
#  ['402,', 'Sllovë,', 'Albania\n'],
#  ['403,', 'Skore,', 'Albania\n'],
#  ['404,', 'Skënderbegas,', 'Albania\n'],
#  ['405,', 'Shushicë,', 'Albania\n'],
#  ['406,', 'Shupenzë,', 'Albania\n'],
#  ['407,', 'Shtiqën,', 'Albania\n'],
#  ['408,', 'Shishtavec,', 'Albania\n'],
#  ['409,', 'Shirgjan,', 'Albania\n'],
#  ['410,', 'Shëngjin,', 'Albania\n'],
#  ['411,', 'Shënmëri,', 'Albania\n'],
#  ['412,', 'Selishtë,', 'Albania\n'],
#  ['413,', 'Saraqinishtë,', 'Albania\n'],
#  ['414,', 'Rukaj,', 'Albania\n'],
#  ['415,', 'Rajcë,', 'Albania\n'],
#  ['416,', 'Roshnik,', 'Albania\n'],
#  ['417,', 'Qukës-Skënderbe,', 'Albania\n'],
#  ['418,', 'Qestorat,', 'Albania\n'],
#  ['419,', 'Qafëmal,', 'Albania\n'],
#  ['420,', 'Përrenjas-Fshat,', 'Albania\n'],
#  ['421,', 'Përrenjas,', 'Albania\n'],
#  ['422,', 'Proptisht,', 'Albania\n'],
#  ['423,', 'Progër,', 'Albania\n'],
#  ['424,', 'Potom,', 'Albania\n'],
#  ['425,', 'Poroçan,', 'Albania\n'],
#  ['426,', 'Polis-Gostimë,', 'Albania\n'],
#  ['427,', 'Poliçan,', 'Albania\n'],
#  ['428,', 'Pojan,', 'Albania\n'],
#  ['429,', 'Pogradec,', 'Albania\n'],
#  ['430,', 'Pishaj,', 'Albania\n'],
#  ['431,', 'Pirg,', 'Albania\n'],
#  ['432,', 'Gjinkar,', 'Albania\n'],
#  ['433,', 'Petran,', 'Albania\n'],
#  ['434,', 'Peshkopi,', 'Albania\n'],
#  ['435,', 'Përmet,', 'Albania\n'],
#  ['436,', 'Ostreni i Math,', 'Albania\n'],
#  ['437,', 'Orosh,', 'Albania\n'],
#  ['438,', 'Orenjë,', 'Albania\n'],
#  ['439,', 'Odrie,', 'Albania\n'],
#  ['440,', 'Novoselë,', 'Albania\n'],
#  ['441,', 'Picar,', 'Albania\n'],
#  ['442,', 'Mollas,', 'Albania\n'],
#  ['443,', 'Mollas,', 'Albania\n'],
#  ['444,', 'Mollaj,', 'Albania\n'],
#  ['445,', 'Miras,', 'Albania\n'],
#  ['446,', 'Melan,', 'Albania\n'],
#  ['447,', 'Mborje,', 'Albania\n'],
#  ['448,', 'Martanesh,', 'Albania\n'],
#  ['449,', 'Maqellarë,', 'Albania\n'],
#  ['450,', 'Maliq,', 'Albania\n'],
#  ['451,', 'Macukull,', 'Albania\n'],
#  ['452,', 'Lunik,', 'Albania\n'],
#  ['453,', 'Llugaj,', 'Albania\n'],
#  ['454,', 'Lis,', 'Albania\n'],
#  ['455,', 'Liqenas,', 'Albania\n'],
#  ['456,', 'Librazhd,', 'Albania\n'],
#  ['457,', 'Libonik,', 'Albania\n'],
#  ['458,', 'Libohovë,', 'Albania\n'],
#  ['459,', 'Leskovik,', 'Albania\n'],
#  ['460,', 'Leshnjë,', 'Albania\n'],
#  ['461,', 'Lenias,', 'Albania\n'],
#  ['462,', 'Lekas,', 'Albania\n'],
#  ['463,', 'Lazarat,', 'Albania\n'],
#  ['464,', 'Labinot-Mal,', 'Albania\n'],
#  ['465,', 'Labinot-Fushë,', 'Albania\n'],
#  ['466,', 'Kushovë,', 'Albania\n'],
#  ['467,', 'Kurbnesh,', 'Albania\n'],
#  ['468,', 'Kukur,', 'Albania\n'],
#  ['469,', 'Kukës,', 'Albania\n'],
#  ['470,', 'Kthella e Epërme,', 'Albania\n'],
#  ['471,', 'Krumë,', 'Albania\n'],
#  ['472,', 'Korçë,', 'Albania\n'],
#  ['473,', 'Kolsh,', 'Albania\n'],
#  ['474,', 'Kodovjat,', 'Albania\n'],
#  ['475,', 'Klos,', 'Albania\n'],
#  ['476,', 'Klos,', 'Albania\n'],
#  ['477,', 'Këlcyrë,', 'Albania\n'],
#  ['478,', 'Kastriot,', 'Albania\n'],
#  ['479,', 'Kardhiq,', 'Albania\n'],
#  ['480,', 'Kalis,', 'Albania\n'],
#  ['481,', 'Iballë,', 'Albania\n'],
#  ['482,', 'Hotolisht,', 'Albania\n'],
#  ['483,', 'Hoçisht,', 'Albania\n'],
#  ['484,', 'Gramsh,', 'Albania\n'],
#  ['485,', 'Gostimë,', 'Albania\n'],
#  ['486,', 'Golaj,', 'Albania\n'],
#  ['487,', 'Gjorica e Sipërme,', 'Albania\n'],
#  ['488,', 'Gjirokastër,', 'Albania\n'],
#  ['489,', 'Gjinar,', 'Albania\n'],
#  ['490,', 'Gjinaj,', 'Albania\n'],
#  ['491,', 'Gjergjan,', 'Albania\n'],
#  ['492,', 'Gjegjan,', 'Albania\n'],
#  ['493,', 'Fushë-Muhurr,', 'Albania\n'],
#  ['494,', 'Fushë-Lurë,', 'Albania\n'],
#  ['495,', 'Fushë-Çidhnë,', 'Albania\n'],
#  ['496,', 'Fushë-Bulqizë,', 'Albania\n'],
#  ['497,', 'Fushë-Arrëz,', 'Albania\n'],
#  ['498,', 'Frashër,', 'Albania\n'],
#  ['499,', 'Fierzë,', 'Albania\n'],
#  ['500,', 'Fajzë,', 'Albania\n'],
#  ['501,', 'Ersekë,', 'Albania\n'],
#  ['502,', 'Elbasan,', 'Albania\n'],
#  ['503,', 'Drenovë,', 'Albania\n'],
#  ['504,', 'Dishnicë,', 'Albania\n'],
#  ['505,', 'Derjan,', 'Albania\n'],
#  ['506,', 'Gjerbës,', 'Albania\n'],
#  ['507,', 'Çorovodë,', 'Albania\n'],
#  ['508,', 'Çlirim,', 'Albania\n'],
#  ['509,', 'Cerava,', 'Albania\n'],
#  ['510,', 'Çepan,', 'Albania\n'],
#  ['511,', 'Çarshovë,', 'Albania\n'],
#  ['512,', 'Kokaj,', 'Albania\n'],
#  ['513,', 'Buz,', 'Albania\n'],
#  ['514,', 'Bushtricë,', 'Albania\n'],
#  ['515,', 'Burrel,', 'Albania\n'],
#  ['516,', 'Bulqizë,', 'Albania\n'],
#  ['517,', 'Bujan,', 'Albania\n'],
#  ['518,', 'Bradashesh,', 'Albania\n'],
#  ['519,', 'Blinisht,', 'Albania\n'],
#  ['520,', 'Blerim,', 'Albania\n'],
#  ['521,', 'Bilisht,', 'Albania\n'],
#  ['522,', 'Bicaj,', 'Albania\n'],
#  ['523,', 'Dardhas,', 'Albania\n'],
#  ['524,', 'Barmash,', 'Albania\n'],
#  ['525,', 'Ballaban,', 'Albania\n'],
#  ['526,', 'Arrën,', 'Albania\n'],
#  ['527,', 'Arras,', 'Albania\n'],
#  ['528,', 'Bytyç,', 'Albania\n'],
#  ['529,', 'Librazhd-Qendër,', 'Albania\n'],
#  ['530,', 'Funarë,', 'Albania\n'],
#  ['531,', 'Moglicë,', 'Albania\n'],
#  ['532,', 'Bogovë,', 'Albania\n'],
#  ['533,', 'Piskovë,', 'Albania\n'],
#  ['534,', 'Lukovë,', 'Albania\n'],
#  ['535,', 'Ksamil,', 'Albania\n'],
#  ['536,', 'Zharrëz,', 'Albania\n'],
#  ['537,', 'Zejmen,', 'Albania\n'],
#  ['538,', 'Zall-Herr,', 'Albania\n'],
#  ['539,', 'Zall-Bastar,', 'Albania\n'],
#  ['540,', 'Xhafzotaj,', 'Albania\n'],
#  ['541,', 'Vukatanë,', 'Albania\n'],
#  ['542,', 'Vranisht,', 'Albania\n'],
#  ['543,', 'Vorë,', 'Albania\n'],
#  ['544,', 'Vlorë,', 'Albania\n'],
#  ['545,', 'Velipojë,', 'Albania\n'],
#  ['546,', 'Velabisht,', 'Albania\n'],
#  ['547,', 'Vaqarr,', 'Albania\n'],
#  ['548,', 'Ura Vajgurore,', 'Albania\n'],
#  ['549,', 'Ungrej,', 'Albania\n'],
#  ['550,', 'Ulëz,', 'Albania\n'],
#  ['551,', 'Topojë,', 'Albania\n'],
#  ['552,', 'Tirana,', 'Albania\n'],
#  ['553,', 'Thumanë,', 'Albania\n'],
#  ['554,', 'Tërbuf,', 'Albania\n'],
#  ['555,', 'Synej,', 'Albania\n'],
#  ['556,', 'Sukth,', 'Albania\n'],
#  ['557,', 'Strum,', 'Albania\n'],
#  ['558,', 'Sinjë,', 'Albania\n'],
#  ['559,', 'Sinaballaj,', 'Albania\n'],
#  ['560,', 'Shkodër,', 'Albania\n'],
#  ['561,', 'Shijak,', 'Albania\n'],
#  ['562,', 'Shezë,', 'Albania\n'],
#  ['563,', 'Shënkoll,', 'Albania\n'],
#  ['564,', 'Shëngjin,', 'Albania\n'],
#  ['565,', 'Shëngjergj,', 'Albania\n'],
#  ['566,', 'Shalës,', 'Albania\n'],
#  ['567,', 'Nicaj-Shalë,', 'Albania\n'],
#  ['568,', 'Sevaster,', 'Albania\n'],
#  ['569,', 'Selitë,', 'Albania\n'],
#  ['570,', 'Valbonë,', 'Albania\n'],
#  ['571,', 'Selenicë,', 'Albania\n'],
#  ['572,', 'Ruzhdie,', 'Albania\n'],
#  ['573,', 'Rubik,', 'Albania\n'],
#  ['574,', 'Rrogozhinë,', 'Albania\n'],
#  ['575,', 'Rrëshen,', 'Albania\n'],
#  ['576,', 'Rrashbull,', 'Albania\n'],
#  ['577,', 'Rrasa e Sipërme,', 'Albania\n'],
#  ['578,', 'Rrapë,', 'Albania\n'],
#  ['579,', 'Roskovec,', 'Albania\n'],
#  ['580,', 'Remas,', 'Albania\n'],
#  ['581,', 'Qerret,', 'Albania\n'],
#  ['582,', 'Qelëz,', 'Albania\n'],
#  ['583,', 'Pukë,', 'Albania\n'],
#  ['584,', 'Progonat,', 'Albania\n'],
#  ['585,', 'Prezë,', 'Albania\n'],
#  ['586,', 'Poshnje,', 'Albania\n'],
#  ['587,', 'Portëz,', 'Albania\n'],
#  ['588,', 'Peza e Madhe,', 'Albania\n'],
#  ['589,', 'Petrelë,', 'Albania\n'],
#  ['590,', 'Përparim,', 'Albania\n'],
#  ['591,', 'Perondi,', 'Albania\n'],
#  ['592,', 'Peqin,', 'Albania\n'],
#  ['593,', 'Patos Fshat,', 'Albania\n'],
#  ['594,', 'Patos,', 'Albania\n'],
#  ['595,', 'Paskuqan,', 'Albania\n'],
#  ['596,', 'Papër,', 'Albania\n'],
#  ['597,', 'Pajovë,', 'Albania\n'],
#  ['598,', 'Otllak,', 'Albania\n'],
#  ['599,', 'Orikum,', 'Albania\n'],
#  ['600,', 'Novoselë,', 'Albania\n'],
#  ['601,', 'Nikël,', 'Albania\n'],
#  ['602,', 'Nicaj-Shosh,', 'Albania\n'],
#  ['603,', 'Ngraçan,', 'Albania\n'],
#  ['604,', 'Ndroq,', 'Albania\n'],
#  ['605,', 'Milot,', 'Albania\n'],
#  ['606,', 'Memaliaj,', 'Albania\n'],
#  ['607,', 'Mbrostar-Urë,', 'Albania\n'],
#  ['608,', 'Manzë,', 'Albania\n'],
#  ['609,', 'Mamurras,', 'Albania\n'],
#  ['610,', 'Maminas,', 'Albania\n'],
#  ['611,', 'Luzi i Vogël,', 'Albania\n'],
#  ['612,', 'Lushnjë,', 'Albania\n'],
#  ['613,', 'Luftinjë,', 'Albania\n'],
#  ['614,', 'Libofshë,', 'Albania\n'],
#  ['615,', 'Lezhë,', 'Albania\n'],
#  ['616,', 'Levan,', 'Albania\n'],
#  ['617,', 'Lekbibaj,', 'Albania\n'],
#  ['618,', 'Lekaj,', 'Albania\n'],
#  ['619,', 'Laç,', 'Albania\n'],
#  ['620,', 'Kutë,', 'Albania\n'],
#  ['621,', 'Kutalli,', 'Albania\n'],
#  ['622,', 'Kurjan,', 'Albania\n'],
#  ['623,', 'Kuman,', 'Albania\n'],
#  ['624,', 'Kuçovë,', 'Albania\n'],
#  ['625,', 'Kuç,', 'Albania\n'],
#  ['626,', 'Kryevidh,', 'Albania\n'],
#  ['627,', 'Krutja e Poshtme,', 'Albania\n'],
#  ['628,', 'Krujë,', 'Albania\n'],
#  ['629,', 'Krrabë,', 'Albania\n'],
#  ['630,', 'Krahës,', 'Albania\n'],
#  ['631,', 'Kozarë,', 'Albania\n'],
#  ['632,', 'Kotë,', 'Albania\n'],
#  ['633,', 'Koplik,', 'Albania\n'],
#  ['634,', 'Kombësi,', 'Albania\n'],
#  ['635,', 'Kolonjë,', 'Albania\n'],
#  ['636,', 'Kolç,', 'Albania\n'],
#  ['637,', 'Kavajë,', 'Albania\n'],
#  ['638,', 'Katundi i Ri,', 'Albania\n'],
#  ['639,', 'Kastrat,', 'Albania\n'],
#  ['640,', 'Kashar,', 'Albania\n'],
#  ['641,', 'Karinë,', 'Albania\n'],
#  ['642,', 'Karbunara e Vogël,', 'Albania\n'],
#  ['643,', 'Kamëz,', 'Albania\n'],
#  ['644,', 'Kallmeti i Madh,', 'Albania\n'],
#  ['645,', 'Kallmet,', 'Albania\n'],
#  ['646,', 'Kalenjë,', 'Albania\n'],
#  ['647,', 'Kajan,', 'Albania\n'],
#  ['648,', 'Kaçinar,', 'Albania\n'],
#  ['649,', 'Ishëm,', 'Albania\n'],
#  ['650,', 'Hysgjokaj,', 'Albania\n'],
#  ['651,', 'Hot,', 'Albania\n'],
#  ['652,', 'Himarë,', 'Albania\n'],
#  ['653,', 'Helmas,', 'Albania\n'],
#  ['654,', 'Hekal,', 'Albania\n'],
#  ['655,', 'Hasan,', 'Albania\n'],
#  ['656,', 'Hajmel,', 'Albania\n'],
#  ['657,', 'Gurra e Vogël,', 'Albania\n'],
#  ['658,', 'Guri i Zi,', 'Albania\n'],
#  ['659,', 'Gruemirë,', 'Albania\n'],
#  ['660,', 'Greshicë,', 'Albania\n'],
#  ['661,', 'Grekan,', 'Albania\n'],
#  ['662,', 'Gradishtë,', 'Albania\n'],
#  ['663,', 'Gracen,', 'Albania\n'],
#  ['664,', 'Grabjan,', 'Albania\n'],
#  ['665,', 'Gosë e Madhe,', 'Albania\n'],
#  ['666,', 'Golem,', 'Albania\n'],
#  ['667,', 'Gjoçaj,', 'Albania\n'],
#  ['668,', 'Gjepalaj,', 'Albania\n'],
#  ['669,', 'Fushëkuqe,', 'Albania\n'],
#  ['670,', 'Fushë-Krujë,', 'Albania\n'],
#  ['671,', 'Fratar,', 'Albania\n'],
#  ['672,', 'Frakulla e Madhe,', 'Albania\n'],
#  ['673,', 'Fier-Shegan,', 'Albania\n'],
#  ['674,', 'Fier-Çifçi,', 'Albania\n'],
#  ['675,', 'Fier,', 'Albania\n'],
#  ['676,', 'Farka e Madhe,', 'Albania\n'],
#  ['677,', 'Durrës,', 'Albania\n'],
#  ['678,', 'Drenovë,', 'Albania\n'],
#  ['679,', 'Divjakë,', 'Albania\n'],
#  ['680,', 'Dërmënas,', 'Albania\n'],
#  ['681,', 'Vau i Dejës,', 'Albania\n'],
#  ['682,', 'Dajt,', 'Albania\n'],
#  ['683,', 'Dajç,', 'Albania\n'],
#  ['684,', 'Dajç,', 'Albania\n'],
#  ['685,', 'Cukalat,', 'Albania\n'],
#  ['686,', 'Cudhi Zall,', 'Albania\n'],
#  ['687,', 'Cërrik,', 'Albania\n'],
#  ['688,', 'Cakran,', 'Albania\n'],
#  ['689,', 'Bushat,', 'Albania\n'],
#  ['690,', 'Bubullimë,', 'Albania\n'],
#  ['691,', 'Bubq,', 'Albania\n'],
#  ['692,', 'Brataj,', 'Albania\n'],
#  ['693,', 'Bërzhitë,', 'Albania\n'],
#  ['694,', 'Bërxull,', 'Albania\n'],
#  ['695,', 'Bërdica e Madhe,', 'Albania\n'],
#  ['696,', 'Berat,', 'Albania\n'],
#  ['697,', 'Belsh,', 'Albania\n'],
#  ['698,', 'Baz,', 'Albania\n'],
#  ['699,', 'Banaj,', 'Albania\n'],
#  ['700,', 'Ballsh,', 'Albania\n'],
#  ['701,', 'Ballagat,', 'Albania\n'],
#  ['702,', 'Baldushk,', 'Albania\n'],
#  ['703,', 'Armen,', 'Albania\n'],
#  ['704,', 'Aranitas,', 'Albania\n'],
#  ['705,', 'Allkaj,', 'Albania\n'],
#  ['706,', 'Golem,', 'Albania\n'],
#  ['707,', 'Balldreni i Ri,', 'Albania\n'],
#  ['708,', 'Grudë-Fushë,', 'Albania\n'],
#  ['709,', 'Fierzë,', 'Albania\n'],
#  ['710,', 'Dushk,', 'Albania\n'],
#  ['711,', 'Selitë,', 'Albania\n'],
#  ['712,', 'Vllahinë,', 'Albania\n'],
#  ['713,', 'Bajram Curri,', 'Albania\n'],
#  ['714,', 'Zarrit’ap’,', 'Armenia\n'],
#  ['715,', 'Zangakatun,', 'Armenia\n'],
#  ['716,', 'Goravan,', 'Armenia\n'],
#  ['717,', 'Yeghegnavan,', 'Armenia\n'],
#  ['718,', 'Yeghegnadzor,', 'Armenia\n'],
#  ['719,', 'Vostan,', 'Armenia\n'],
#  ['720,', 'Vosketap’,', 'Armenia\n'],
#  ['721,', 'Vernashen,', 'Armenia\n'],
#  ['722,', 'Verishen,', 'Armenia\n'],
#  ['723,', 'Vedi,', 'Armenia\n'],
#  ['724,', 'Vayk’,', 'Armenia\n'],
#  ['725,', 'Tegh,', 'Armenia\n'],
#  ['726,', 'Surenavan,', 'Armenia\n'],
#  ['727,', 'Sisavan,', 'Armenia\n'],
#  ['728,', 'Shinuhayr,', 'Armenia\n'],
#  ['729,', 'Lusarrat,', 'Armenia\n'],
#  ['730,', 'Shahumyan,', 'Armenia\n'],
#  ['731,', 'Shatin,', 'Armenia\n'],
#  ['732,', 'Shaghat,', 'Armenia\n'],
#  ['733,', 'Rrind,', 'Armenia\n'],
#  ['734,', 'Noyakert,', 'Armenia\n'],
#  ['735,', 'Mrgavan,', 'Armenia\n'],
#  ['736,', 'Meghri,', 'Armenia\n'],
#  ['737,', 'Malishka,', 'Armenia\n'],
#  ['738,', 'Khndzoresk,', 'Armenia\n'],
#  ['739,', 'Kapan,', 'Armenia\n'],
#  ['740,', 'Jermuk,', 'Armenia\n'],
#  ['741,', 'Goris,', 'Armenia\n'],
#  ['742,', 'Gladzor,', 'Armenia\n'],
#  ['743,', 'Getap’,', 'Armenia\n'],
#  ['744,', 'Dzorastan,', 'Armenia\n'],
#  ['745,', 'Dalar,', 'Armenia\n'],
#  ['746,', 'Burastan,', 'Armenia\n'],
#  ['747,', 'Akner,', 'Armenia\n'],
#  ['748,', 'Brrnakot’,', 'Armenia\n'],
#  ['749,', 'Berk’anush,', 'Armenia\n'],
#  ['750,', 'Aygezard,', 'Armenia\n'],
#  ['751,', 'Aygepat,', 'Armenia\n'],
#  ['752,', 'Aygavan,', 'Armenia\n'],
#  ['753,', 'Avshar,', 'Armenia\n'],
#  ['754,', 'Hats’avan,', 'Armenia\n'],
#  ['755,', 'Artashat,', 'Armenia\n'],
#  ['756,', 'Yeghegis,', 'Armenia\n'],
#  ['757,', 'Armash,', 'Armenia\n'],
#  ['758,', 'Areni,', 'Armenia\n'],
#  ['759,', 'Ararat,', 'Armenia\n'],
#  ['760,', 'Angeghakot’,', 'Armenia\n'],
#  ['761,', 'Aghavnadzor,', 'Armenia\n'],
#  ['762,', 'Agarakadzor,', 'Armenia\n'],
#  ['763,', 'Agarak,', 'Armenia\n'],
#  ['764,', 'Aralez,', 'Armenia\n'],
#  ['765,', 'Horrom,', 'Armenia\n'],
#  ['766,', 'Margara,', 'Armenia\n'],
#  ['767,', 'Zovuni,', 'Armenia\n'],
#  ['768,', 'Zovaber,', 'Armenia\n'],
#  ['769,', 'Zorak,', 'Armenia\n'],
#  ['770,', 'Zarr,', 'Armenia\n'],
#  ['771,', 'Yerevan,', 'Armenia\n'],
#  ['772,', 'Yerazgavors,', 'Armenia\n'],
#  ['773,', 'Yeraskhahun,', 'Armenia\n'],
#  ['774,', 'Yeranos,', 'Armenia\n'],
#  ['775,', 'Yeghegnut,', 'Armenia\n'],
#  ['776,', 'Yeghegnut,', 'Armenia\n'],
#  ['777,', 'Vagharshapat,', 'Armenia\n'],
#  ['778,', 'Yeghvard,', 'Armenia\n'],
#  ['779,', 'Voskevaz,', 'Armenia\n'],
#  ['780,', 'Voskevan,', 'Armenia\n'],
#  ['781,', 'Voskehask,', 'Armenia\n'],
#  ['782,', 'Verin Getashen,', 'Armenia\n'],
#  ['783,', 'Verin Dvin,', 'Armenia\n'],
#  ['784,', 'Verin Artashat,', 'Armenia\n'],
#  ['785,', 'Akht’ala,', 'Armenia\n'],
#  ['786,', 'Varser,', 'Armenia\n'],
#  ['787,', 'Vardenis,', 'Armenia\n'],
#  ['788,', 'Vardenik,', 'Armenia\n'],
#  ['789,', 'Vahan,', 'Armenia\n'],
#  ['790,', 'Vaghashen,', 'Armenia\n'],
#  ['791,', 'Vahagni,', 'Armenia\n'],
#  ['792,', 'Ushi,', 'Armenia\n'],
#  ['793,', 'Urrut,', 'Armenia\n'],
#  ['794,', 'Tsovinar,', 'Armenia\n'],
#  ['795,', 'Tsovazard,', 'Armenia\n'],
#  ['796,', 'Tsovak,', 'Armenia\n'],
#  ['797,', 'Tsovagyugh,', 'Armenia\n'],
#  ['798,', 'Tsaghkunk’,', 'Armenia\n'],
#  ['799,', 'Tsaghkahovit,', 'Armenia\n'],
#  ['800,', 'Tsaghkaber,', 'Armenia\n'],
#  ['801,', 'Tsaghkadzor,', 'Armenia\n'],
#  ['802,', 'Tsovasar,', 'Armenia\n'],
#  ['803,', 'Tashir,', 'Armenia\n'],
#  ['804,', 'Tandzut,', 'Armenia\n'],
#  ['805,', 'T’alin,', 'Armenia\n'],
#  ['806,', 'Step’anavan,', 'Armenia\n'],
#  ['807,', 'Spitak,', 'Armenia\n'],
#  ['808,', 'Spandaryan,', 'Armenia\n'],
#  ['809,', 'Alashkert,', 'Armenia\n'],
#  ['810,', 'Solak,', 'Armenia\n'],
#  ['811,', 'Sis,', 'Armenia\n'],
#  ['812,', 'Shnogh,', 'Armenia\n'],
#  ['813,', 'Shirak,', 'Armenia\n'],
#  ['814,', 'Shenavan,', 'Armenia\n'],
#  ['815,', 'Shenavan,', 'Armenia\n'],
#  ['816,', 'Sevan,', 'Armenia\n'],
#  ['817,', 'Sarukhan,', 'Armenia\n'],
#  ['818,', 'Sarigyugh,', 'Armenia\n'],
#  ['819,', 'Saratak,', 'Armenia\n'],
#  ['820,', 'Saramej,', 'Armenia\n'],
#  ['821,', 'Sarahart’,', 'Armenia\n'],
#  ['822,', 'Geghakert,', 'Armenia\n'],
#  ['823,', 'Ptghni,', 'Armenia\n'],
#  ['824,', 'Ptghunk’,', 'Armenia\n'],
#  ['825,', 'P’shatavan,', 'Armenia\n'],
#  ['826,', 'Prroshyan,', 'Armenia\n'],
#  ['827,', 'P’ok’r Mant’ash,', 'Armenia\n'],
#  ['828,', 'Zoravan,', 'Armenia\n'],
#  ['829,', 'Pemzashen,', 'Armenia\n'],
#  ['830,', 'Parravak’ar,', 'Armenia\n'],
#  ['831,', 'Oshakan,', 'Armenia\n'],
#  ['832,', 'Sardarapat,', 'Armenia\n'],
#  ['833,', 'Odzun,', 'Armenia\n'],
#  ['834,', 'Noyemberyan,', 'Armenia\n'],
#  ['835,', 'Nor Gyugh,', 'Armenia\n'],
#  ['836,', 'Nor Geghi,', 'Armenia\n'],
#  ['837,', 'Norashen,', 'Armenia\n'],
#  ['838,', 'Norashen,', 'Armenia\n'],
#  ['839,', 'Nor Armavir,', 'Armenia\n'],
#  ['840,', 'Noramarg,', 'Armenia\n'],
#  ['841,', 'Norakert,', 'Armenia\n'],
#  ['842,', 'Noratus,', 'Armenia\n'],
#  ['843,', 'Nerk’in Getashen,', 'Armenia\n'],
#  ['844,', 'Navur,', 'Armenia\n'],
#  ['845,', 'Nalbandyan,', 'Armenia\n'],
#  ['846,', 'Basen,', 'Armenia\n'],
#  ['847,', 'Hovtamej,', 'Armenia\n'],
#  ['848,', 'Mrgashen,', 'Armenia\n'],
#  ['849,', 'Mrgashat,', 'Armenia\n'],
#  ['850,', 'Mrganush,', 'Armenia\n'],
#  ['851,', 'Mosesgegh,', 'Armenia\n'],
#  ['852,', 'Mets Parni,', 'Armenia\n'],
#  ['853,', 'Mets Masrik,', 'Armenia\n'],
#  ['854,', 'Mets Mant’ash,', 'Armenia\n'],
#  ['855,', 'Metsavan,', 'Armenia\n'],
#  ['856,', 'Metsamor,', 'Armenia\n'],
#  ['857,', 'Merdzavan,', 'Armenia\n'],
#  ['858,', 'Meghrashen,', 'Armenia\n'],
#  ['859,', 'Meghradzor,', 'Armenia\n'],
#  ['860,', 'Mayakovski,', 'Armenia\n'],
#  ['861,', 'Masis,', 'Armenia\n'],
#  ['862,', 'Martuni,', 'Armenia\n'],
#  ['863,', 'Marmarashen,', 'Armenia\n'],
#  ['864,', 'Marmashen,', 'Armenia\n'],
#  ['865,', 'Margahovit,', 'Armenia\n'],
#  ['866,', 'Maralik,', 'Armenia\n'],
#  ['867,', 'Mayisyan,', 'Armenia\n'],
#  ['868,', 'Madina,', 'Armenia\n'],
#  ['869,', 'Lukashin,', 'Armenia\n'],
#  ['870,', 'Lorut,', 'Armenia\n'],
#  ['871,', 'Lichk’,', 'Armenia\n'],
#  ['872,', 'Lerrnavan,', 'Armenia\n'],
#  ['873,', 'Lerrnapat,', 'Armenia\n'],
#  ['874,', 'Lerrnants’k’,', 'Armenia\n'],
#  ['875,', 'Lerrnanist,', 'Armenia\n'],
#  ['876,', 'Lerrnakert,', 'Armenia\n'],
#  ['877,', 'Khoronk’,', 'Armenia\n'],
#  ['878,', 'Lchashen,', 'Armenia\n'],
#  ['879,', 'Lchap’,', 'Armenia\n'],
#  ['880,', 'Lanjaghbyur,', 'Armenia\n'],
#  ['881,', 'Kotayk’,', 'Armenia\n'],
#  ['882,', 'Kosh,', 'Armenia\n'],
#  ['883,', 'Vanadzor,', 'Armenia\n'],
#  ['884,', 'Hnaberd,', 'Armenia\n'],
#  ['885,', 'Khasht’arrak,', 'Armenia\n'],
#  ['886,', 'Kasakh,', 'Armenia\n'],
#  ['887,', 'Karchaghbyur,', 'Armenia\n'],
#  ['888,', 'Karbi,', 'Armenia\n'],
#  ['889,', 'Karanlukh,', 'Armenia\n'],
#  ['890,', 'Kaputan,', 'Armenia\n'],
#  ['891,', 'K’anak’erravan,', 'Armenia\n'],
#  ['892,', 'Kamo,', 'Armenia\n'],
#  ['893,', 'Gavarr,', 'Armenia\n'],
#  ['894,', 'Mayisyan,', 'Armenia\n'],
#  ['895,', 'Shahumyan,', 'Armenia\n'],
#  ['896,', 'Ijevan,', 'Armenia\n'],
#  ['897,', 'Hrazdan,', 'Armenia\n'],
#  ['898,', 'Armavir,', 'Armenia\n'],
#  ['899,', 'Hayanist,', 'Armenia\n'],
#  ['900,', 'Haghartsin,', 'Armenia\n'],
#  ['901,', 'Gyumri,', 'Armenia\n'],
#  ['902,', 'Gyulagarak,', 'Armenia\n'],
#  ['903,', 'Ghukasavan,', 'Armenia\n'],
#  ['904,', 'Geghamasar,', 'Armenia\n'],
#  ['905,', 'Gugark’,', 'Armenia\n'],
#  ['906,', 'Tsiatsan,', 'Armenia\n'],
#  ['907,', 'Goght’,', 'Armenia\n'],
#  ['908,', 'Gogaran,', 'Armenia\n'],
#  ['909,', 'Getazat,', 'Armenia\n'],
#  ['910,', 'Getashen,', 'Armenia\n'],
#  ['911,', 'Geghanist,', 'Armenia\n'],
#  ['912,', 'Geghamavan,', 'Armenia\n'],
#  ['913,', 'Garrni,', 'Armenia\n'],
#  ['914,', 'Gagarin,', 'Armenia\n'],
#  ['915,', 'Fantan,', 'Armenia\n'],
#  ['916,', 'Fioletovo,', 'Armenia\n'],
#  ['917,', 'Dzoraghbyur,', 'Armenia\n'],
#  ['918,', 'Dzoragyugh,', 'Armenia\n'],
#  ['919,', 'Dzit’hank’ov,', 'Armenia\n'],
#  ['920,', 'Jrashen,', 'Armenia\n'],
#  ['921,', 'Jrashen,', 'Armenia\n'],
#  ['922,', 'Jrahovit,', 'Armenia\n'],
#  ['923,', 'Janfida,', 'Armenia\n'],
#  ['924,', 'Dvin,', 'Armenia\n'],
#  ['925,', 'Dsegh,', 'Armenia\n'],
#  ['926,', 'Drakhtik,', 'Armenia\n'],
#  ['927,', 'Doghs,', 'Armenia\n'],
#  ['928,', 'Dilijan,', 'Armenia\n'],
#  ['929,', 'Ddmashen,', 'Armenia\n'],
#  ['930,', 'Darpas,', 'Armenia\n'],
#  ['931,', 'Dalarik,', 'Armenia\n'],
#  ['932,', 'Chochkan,', 'Armenia\n'],
#  ['933,', 'Chambarak,', 'Armenia\n'],
#  ['934,', 'Bjni,', 'Armenia\n'],
#  ['935,', 'Byureghavan,', 'Armenia\n'],
#  ['936,', 'Byurakan,', 'Armenia\n'],
#  ['937,', 'Buzhakan,', 'Armenia\n'],
#  ['938,', 'Berd,', 'Armenia\n'],
#  ['939,', 'Bazum,', 'Armenia\n'],
#  ['940,', 'Byuravan,', 'Armenia\n'],
#  ['941,', 'Bambakashat,', 'Armenia\n'],
#  ['942,', 'Balahovit,', 'Armenia\n'],
#  ['943,', 'Bagratashen,', 'Armenia\n'],
#  ['944,', 'Azatan,', 'Armenia\n'],
#  ['945,', 'Haykavan,', 'Armenia\n'],
#  ['946,', 'Aygestan,', 'Armenia\n'],
#  ['947,', 'Aygeshat,', 'Armenia\n'],
#  ['948,', 'Aygeshat,', 'Armenia\n'],
#  ['949,', 'Aknalich,', 'Armenia\n'],
#  ['950,', 'Aygehovit,', 'Armenia\n'],
#  ['951,', 'Artimet,', 'Armenia\n'],
#  ['952,', 'Astghadzor,', 'Armenia\n'],
#  ['953,', 'Ashtarak,', 'Armenia\n'],
#  ['954,', 'Ashnak,', 'Armenia\n'],
#  ['955,', 'Arzni,', 'Armenia\n'],
#  ['956,', 'Arzakan,', 'Armenia\n'],
#  ['957,', 'Arteni,', 'Armenia\n'],
#  ['958,', 'Arshaluys,', 'Armenia\n'],
#  ['959,', 'Argel,', 'Armenia\n'],
#  ['960,', 'Argavand,', 'Armenia\n'],
#  ['961,', 'Argavand,', 'Armenia\n'],
#  ['962,', 'Arevshat,', 'Armenia\n'],
#  ['963,', 'Arevshat,', 'Armenia\n'],
#  ['964,', 'Arevik,', 'Armenia\n'],
#  ['965,', 'Arevik,', 'Armenia\n'],
#  ['966,', 'Arevashogh,', 'Armenia\n'],
#  ['967,', 'Arevashat,', 'Armenia\n'],
#  ['968,', 'Archis,', 'Armenia\n'],
#  ['969,', 'Arbat’,', 'Armenia\n'],
#  ['970,', 'Arazap’,', 'Armenia\n'],
#  ['971,', 'Arrap’i,', 'Armenia\n'],
#  ['972,', 'Aramus,', 'Armenia\n'],
#  ['973,', 'Arak’s,', 'Armenia\n'],
#  ['974,', 'Aragats,', 'Armenia\n'],
#  ['975,', 'Aparan,', 'Armenia\n'],
#  ['976,', 'Apaga,', 'Armenia\n'],
#  ['977,', 'Anushavan,', 'Armenia\n'],
#  ['978,', 'Amasia,', 'Armenia\n'],
#  ['979,', 'Alaverdi,', 'Armenia\n'],
#  ['980,', 'Akunk’,', 'Armenia\n'],
#  ['981,', 'Akunk’,', 'Armenia\n'],
#  ['982,', 'Akhuryan,', 'Armenia\n'],
#  ['983,', 'Aghavnatun,', 'Armenia\n'],
#  ['984,', 'Aghavnadzor,', 'Armenia\n'],
#  ['985,', 'Agarak,', 'Armenia\n'],
#  ['986,', 'Agarakavan,', 'Armenia\n'],
#  ['987,', 'Abovyan,', 'Armenia\n'],
#  ['988,', 'Abovyan,', 'Armenia\n'],
#  ['989,', 'Vardablur,', 'Armenia\n'],
#  ['990,', 'Bardzrashen,', 'Armenia\n'],
#  ['991,', 'Nshavan,', 'Armenia\n'],
#  ['992,', 'Norabats’,', 'Armenia\n'],
#  ['993,', 'Berdavan,', 'Armenia\n'],
#  ['994,', 'Shirakamut,', 'Armenia\n'],
#  ['995,', 'Azatamut,', 'Armenia\n'],
#  ['996,', 'Artsvaberd,', 'Armenia\n'],
#  ['997,', 'Nor Yerznka,', 'Armenia\n'],
#  ['998,', 'Sasunik,', 'Armenia\n'],
#  ...]

# %%
data_1[-1]
# Out:
# ['132423,', 'Chitungwiza,', 'Zimbabwe\n']

# %%
#Read the list of cities in Sweden:
def swedish_cities(filename, data):
    #filename = swedish cities list (cities_sweden.csv)
    #data = final_data's output
    
    #This function reads the data (list of cities in Sweden from 'cities_sweden.csv') 
    #and creates a new list where each element is represented as [Swedish city name, Sweden]. Next, each 
    #element is appended to the list we obtained from running 'final_data' with the rest of city/country names.
    
    swe_data = [] #list of Swedish cities
    items_zero = [] #list of numbers (first elements of each line in the final data)
    #all_data = [] #combo = list of numbers + [Swedish city name, Sweden]

    with open(filename, 'r') as read_obj:
            csv_reader = reader(read_obj)
            header = next(csv_reader)
            
            for row in csv_reader:
            #row variable is a list that represents a row in csv
                row[1] += ',' #we add a comma to the city name
                #country = 'Sweden\n'
                swe_data.append(row[1])
    
    
    index = data[-1][0] #last line, first element -- (line count)
    last_num = int(index[:-1]) + 1 #integer of index without the comma
    len_swe = len(swe_data) #number of Swedish cities we will add to the final data
    end = last_num + len_swe #we use this to create a list of numbers (line count) with the items[0] in the final data

    for number in range(last_num, end):
        x = str(number)
        x += ','
        items_zero.append(x)
    
    dic = {}
    for key in items_zero:
        for value in swe_data:
            dic[key] = value
            swe_data.remove(value)
            break
    
    all_data = []
    for item in items_zero:
        x = dic[item]
        final_item = [str(item), x, 'Sweden\n']
        all_data.append(final_item)
    
    
    for item in all_data:
        data.append(item)
    
    #for item in data:
        #print('item:', item[1])
        #if item[1] == ',' and item[2] == '\n':
            #item[1] += 'Chitungwiza,')
            #item[2] += 'Zimbabwe\n'
        
    return data

# %%
data_update_1 = swedish_cities(cities_sweden, data_1)

# %%
data_update_1[-320:]
# Out:
# [['132422,', 'Epworth,', 'Zimbabwe\n'],
#  ['132423,', 'Chitungwiza,', 'Zimbabwe\n'],
#  ['132424,', 'Alfta,', 'Sweden\n'],
#  ['132425,', 'Alingsås,', 'Sweden\n'],
#  ['132426,', 'Alvesta,', 'Sweden\n'],
#  ['132427,', 'Aneby,', 'Sweden\n'],
#  ['132428,', 'Arboga,', 'Sweden\n'],
#  ['132429,', 'Arjeplog,', 'Sweden\n'],
#  ['132430,', 'Arlöv,', 'Sweden\n'],
#  ['132431,', 'Arvidsjaur,', 'Sweden\n'],
#  ['132432,', 'Arvika,', 'Sweden\n'],
#  ['132433,', 'Askersund,', 'Sweden\n'],
#  ['132434,', 'Avesta,', 'Sweden\n'],
#  ['132435,', 'Bengtsfors,', 'Sweden\n'],
#  ['132436,', 'Bergsjö,', 'Sweden\n'],
#  ['132437,', 'Bjuv,', 'Sweden\n'],
#  ['132438,', 'Boden,', 'Sweden\n'],
#  ['132439,', 'Boliden,', 'Sweden\n'],
#  ['132440,', 'Bollebygd,', 'Sweden\n'],
#  ['132441,', 'Bollnäs,', 'Sweden\n'],
#  ['132442,', 'Borgholm,', 'Sweden\n'],
#  ['132443,', 'Borlänge,', 'Sweden\n'],
#  ['132444,', 'Borås,', 'Sweden\n'],
#  ['132445,', 'Boxholm,', 'Sweden\n'],
#  ['132446,', 'Bredbyn,', 'Sweden\n'],
#  ['132447,', 'Broby,', 'Sweden\n'],
#  ['132448,', 'Bromölla,', 'Sweden\n'],
#  ['132449,', 'Bräcke,', 'Sweden\n'],
#  ['132450,', 'Burträsk,', 'Sweden\n'],
#  ['132451,', 'Byske,', 'Sweden\n'],
#  ['132452,', 'Bålsta,', 'Sweden\n'],
#  ['132453,', 'Båstad,', 'Sweden\n'],
#  ['132454,', 'Charlottenberg,', 'Sweden\n'],
#  ['132455,', 'Degerfors,', 'Sweden\n'],
#  ['132456,', 'Djursholm,', 'Sweden\n'],
#  ['132457,', 'Dorotea,', 'Sweden\n'],
#  ['132458,', 'Ed,', 'Sweden\n'],
#  ['132459,', 'Edsbyn,', 'Sweden\n'],
#  ['132460,', 'Ekerö,', 'Sweden\n'],
#  ['132461,', 'Ekshärad,', 'Sweden\n'],
#  ['132462,', 'Eksjö,', 'Sweden\n'],
#  ['132463,', 'Emmaboda,', 'Sweden\n'],
#  ['132464,', 'Enköping,', 'Sweden\n'],
#  ['132465,', 'Eskilstuna,', 'Sweden\n'],
#  ['132466,', 'Eslöv,', 'Sweden\n'],
#  ['132467,', 'Fagersta,', 'Sweden\n'],
#  ['132468,', 'Falkenberg,', 'Sweden\n'],
#  ['132469,', 'Falköping,', 'Sweden\n'],
#  ['132470,', 'Falun,', 'Sweden\n'],
#  ['132471,', 'Filipstad,', 'Sweden\n'],
#  ['132472,', 'Finspång,', 'Sweden\n'],
#  ['132473,', 'Fjugesta,', 'Sweden\n'],
#  ['132474,', 'Flen,', 'Sweden\n'],
#  ['132475,', 'Forshaga,', 'Sweden\n'],
#  ['132476,', 'Färgelanda,', 'Sweden\n'],
#  ['132477,', 'Färjestaden,', 'Sweden\n'],
#  ['132478,', 'Gagnef,', 'Sweden\n'],
#  ['132479,', 'Garphyttan,', 'Sweden\n'],
#  ['132480,', 'Gislaved,', 'Sweden\n'],
#  ['132481,', 'Gnesta,', 'Sweden\n'],
#  ['132482,', 'Gnosjö,', 'Sweden\n'],
#  ['132483,', 'Grebbestad,', 'Sweden\n'],
#  ['132484,', 'Grums,', 'Sweden\n'],
#  ['132485,', 'Gränna,', 'Sweden\n'],
#  ['132486,', 'Grästorp,', 'Sweden\n'],
#  ['132487,', 'Gullspång,', 'Sweden\n'],
#  ['132488,', 'Gustavsberg,', 'Sweden\n'],
#  ['132489,', 'Gällivare,', 'Sweden\n'],
#  ['132490,', 'Gävle,', 'Sweden\n'],
#  ['132491,', 'Göteborg,', 'Sweden\n'],
#  ['132492,', 'Götene,', 'Sweden\n'],
#  ['132493,', 'Habo,', 'Sweden\n'],
#  ['132494,', 'Hagfors,', 'Sweden\n'],
#  ['132495,', 'Hallsberg,', 'Sweden\n'],
#  ['132496,', 'Hallstahammar,', 'Sweden\n'],
#  ['132497,', 'Halmstad,', 'Sweden\n'],
#  ['132498,', 'Hammarstrand,', 'Sweden\n'],
#  ['132499,', 'Handen,', 'Sweden\n'],
#  ['132500,', 'Haparanda,', 'Sweden\n'],
#  ['132501,', 'Heby,', 'Sweden\n'],
#  ['132502,', 'Hedemora,', 'Sweden\n'],
#  ['132503,', 'Helsingborg,', 'Sweden\n'],
#  ['132504,', 'Hemse,', 'Sweden\n'],
#  ['132505,', 'Henån,', 'Sweden\n'],
#  ['132506,', 'Herrljunga,', 'Sweden\n'],
#  ['132507,', 'Hjo,', 'Sweden\n'],
#  ['132508,', 'Hofors,', 'Sweden\n'],
#  ['132509,', 'Holmsund,', 'Sweden\n'],
#  ['132510,', 'Huddinge,', 'Sweden\n'],
#  ['132511,', 'Hudiksvall,', 'Sweden\n'],
#  ['132512,', 'Hultsfred,', 'Sweden\n'],
#  ['132513,', 'Hunnebostrand,', 'Sweden\n'],
#  ['132514,', 'Hyltebruk,', 'Sweden\n'],
#  ['132515,', 'Hällefors,', 'Sweden\n'],
#  ['132516,', 'Härnösand,', 'Sweden\n'],
#  ['132517,', 'Hässleholm,', 'Sweden\n'],
#  ['132518,', 'Höganäs,', 'Sweden\n'],
#  ['132519,', 'Högsby,', 'Sweden\n'],
#  ['132520,', 'Hörby,', 'Sweden\n'],
#  ['132521,', 'Hörnefors,', 'Sweden\n'],
#  ['132522,', 'Höör,', 'Sweden\n'],
#  ['132523,', 'Jakobsberg,', 'Sweden\n'],
#  ['132524,', 'Jokkmokk,', 'Sweden\n'],
#  ['132525,', 'Järvsö,', 'Sweden\n'],
#  ['132526,', 'Jönköping,', 'Sweden\n'],
#  ['132527,', 'Kalix,', 'Sweden\n'],
#  ['132528,', 'Kalmar,', 'Sweden\n'],
#  ['132529,', 'Karlsborg,', 'Sweden\n'],
#  ['132530,', 'Karlshamn,', 'Sweden\n'],
#  ['132531,', 'Karlskoga,', 'Sweden\n'],
#  ['132532,', 'Karlskrona,', 'Sweden\n'],
#  ['132533,', 'Karlstad,', 'Sweden\n'],
#  ['132534,', 'Katrineholm,', 'Sweden\n'],
#  ['132535,', 'Kil,', 'Sweden\n'],
#  ['132536,', 'Kinna,', 'Sweden\n'],
#  ['132537,', 'Kiruna,', 'Sweden\n'],
#  ['132538,', 'Kisa,', 'Sweden\n'],
#  ['132539,', 'Kista,', 'Sweden\n'],
#  ['132540,', 'Kivik,', 'Sweden\n'],
#  ['132541,', 'Klintehamn,', 'Sweden\n'],
#  ['132542,', 'Klippan,', 'Sweden\n'],
#  ['132543,', 'Knivsta,', 'Sweden\n'],
#  ['132544,', 'Kopparberg,', 'Sweden\n'],
#  ['132545,', 'Kramfors,', 'Sweden\n'],
#  ['132546,', 'Kristianstad,', 'Sweden\n'],
#  ['132547,', 'Kristinehamn,', 'Sweden\n'],
#  ['132548,', 'Krokom,', 'Sweden\n'],
#  ['132549,', 'Kumla,', 'Sweden\n'],
#  ['132550,', 'Kungsbacka,', 'Sweden\n'],
#  ['132551,', 'Kungshamn,', 'Sweden\n'],
#  ['132552,', 'Kungsängen,', 'Sweden\n'],
#  ['132553,', 'Kungsör,', 'Sweden\n'],
#  ['132554,', 'Kungälv,', 'Sweden\n'],
#  ['132555,', 'Kävlinge,', 'Sweden\n'],
#  ['132556,', 'Kåge,', 'Sweden\n'],
#  ['132557,', 'Köping,', 'Sweden\n'],
#  ['132558,', 'Laholm,', 'Sweden\n'],
#  ['132559,', 'Landskrona,', 'Sweden\n'],
#  ['132560,', 'Laxå,', 'Sweden\n'],
#  ['132561,', 'Leksand,', 'Sweden\n'],
#  ['132562,', 'Lerum,', 'Sweden\n'],
#  ['132563,', 'Lessebo,', 'Sweden\n'],
#  ['132564,', 'Lidingö,', 'Sweden\n'],
#  ['132565,', 'Lidköping,', 'Sweden\n'],
#  ['132566,', 'Lilla Edet,', 'Sweden\n'],
#  ['132567,', 'Lindesberg,', 'Sweden\n'],
#  ['132568,', 'Lindome,', 'Sweden\n'],
#  ['132569,', 'Linköping,', 'Sweden\n'],
#  ['132570,', 'Ljungby,', 'Sweden\n'],
#  ['132571,', 'Ljusdal,', 'Sweden\n'],
#  ['132572,', 'Lomma,', 'Sweden\n'],
#  ['132573,', 'Ludvika,', 'Sweden\n'],
#  ['132574,', 'Luleå,', 'Sweden\n'],
#  ['132575,', 'Lund,', 'Sweden\n'],
#  ['132576,', 'Lycksele,', 'Sweden\n'],
#  ['132577,', 'Lysekil,', 'Sweden\n'],
#  ['132578,', 'Majorna,', 'Sweden\n'],
#  ['132579,', 'Malmberget,', 'Sweden\n'],
#  ['132580,', 'Malmö,', 'Sweden\n'],
#  ['132581,', 'Malung,', 'Sweden\n'],
#  ['132582,', 'Malå,', 'Sweden\n'],
#  ['132583,', 'Mariestad,', 'Sweden\n'],
#  ['132584,', 'Markaryd,', 'Sweden\n'],
#  ['132585,', 'Marstrand,', 'Sweden\n'],
#  ['132586,', 'Mellerud,', 'Sweden\n'],
#  ['132587,', 'Mjölby,', 'Sweden\n'],
#  ['132588,', 'Mora,', 'Sweden\n'],
#  ['132589,', 'Motala,', 'Sweden\n'],
#  ['132590,', 'Munkedal,', 'Sweden\n'],
#  ['132591,', 'Märsta,', 'Sweden\n'],
#  ['132592,', 'Mölndal,', 'Sweden\n'],
#  ['132593,', 'Mölnlycke,', 'Sweden\n'],
#  ['132594,', 'Mönsterås,', 'Sweden\n'],
#  ['132595,', 'Mörbylånga,', 'Sweden\n'],
#  ['132596,', 'Nacka,', 'Sweden\n'],
#  ['132597,', 'Njurundabommen,', 'Sweden\n'],
#  ['132598,', 'Nora,', 'Sweden\n'],
#  ['132599,', 'Norberg,', 'Sweden\n'],
#  ['132600,', 'Nordmaling,', 'Sweden\n'],
#  ['132601,', 'Norrköping,', 'Sweden\n'],
#  ['132602,', 'Norrtälje,', 'Sweden\n'],
#  ['132603,', 'Norsjö,', 'Sweden\n'],
#  ['132604,', 'Nossebro,', 'Sweden\n'],
#  ['132605,', 'Nybro,', 'Sweden\n'],
#  ['132606,', 'Nyköping,', 'Sweden\n'],
#  ['132607,', 'Nynäshamn,', 'Sweden\n'],
#  ['132608,', 'Nässjö,', 'Sweden\n'],
#  ['132609,', 'Ockelbo,', 'Sweden\n'],
#  ['132610,', 'Olofström,', 'Sweden\n'],
#  ['132611,', 'Onsala,', 'Sweden\n'],
#  ['132612,', 'Orsa,', 'Sweden\n'],
#  ['132613,', 'Osby,', 'Sweden\n'],
#  ['132614,', 'Oskarshamn,', 'Sweden\n'],
#  ['132615,', 'Oxelösund,', 'Sweden\n'],
#  ['132616,', 'Pajala,', 'Sweden\n'],
#  ['132617,', 'Partille,', 'Sweden\n'],
#  ['132618,', 'Perstorp,', 'Sweden\n'],
#  ['132619,', 'Piteå,', 'Sweden\n'],
#  ['132620,', 'Rimforsa,', 'Sweden\n'],
#  ['132621,', 'Robertsfors,', 'Sweden\n'],
#  ['132622,', 'Ronneby,', 'Sweden\n'],
#  ['132623,', 'Rättvik,', 'Sweden\n'],
#  ['132624,', 'Råneå,', 'Sweden\n'],
#  ['132625,', 'Sala,', 'Sweden\n'],
#  ['132626,', 'Salem,', 'Sweden\n'],
#  ['132627,', 'Sandviken,', 'Sweden\n'],
#  ['132628,', 'Sigtuna,', 'Sweden\n'],
#  ['132629,', 'Simrishamn,', 'Sweden\n'],
#  ['132630,', 'Sjöbo,', 'Sweden\n'],
#  ['132631,', 'Skara,', 'Sweden\n'],
#  ['132632,', 'Skellefteå,', 'Sweden\n'],
#  ['132633,', 'Skinnskatteberg,', 'Sweden\n'],
#  ['132634,', 'Skoghall,', 'Sweden\n'],
#  ['132635,', 'Skurup,', 'Sweden\n'],
#  ['132636,', 'Skutskär,', 'Sweden\n'],
#  ['132637,', 'Skärhamn,', 'Sweden\n'],
#  ['132638,', 'Skövde,', 'Sweden\n'],
#  ['132639,', 'Slite,', 'Sweden\n'],
#  ['132640,', 'Smedjebacken,', 'Sweden\n'],
#  ['132641,', 'Smögen,', 'Sweden\n'],
#  ['132642,', 'Sollefteå,', 'Sweden\n'],
#  ['132643,', 'Sollentuna,', 'Sweden\n'],
#  ['132644,', 'Sorsele,', 'Sweden\n'],
#  ['132645,', 'Staffanstorp,', 'Sweden\n'],
#  ['132646,', 'Stenungsund,', 'Sweden\n'],
#  ['132647,', 'Stockholm,', 'Sweden\n'],
#  ['132648,', 'Storfors,', 'Sweden\n'],
#  ['132649,', 'Storuman,', 'Sweden\n'],
#  ['132650,', 'Strängnäs,', 'Sweden\n'],
#  ['132651,', 'Strömstad,', 'Sweden\n'],
#  ['132652,', 'Strömsund,', 'Sweden\n'],
#  ['132653,', 'Sundbyberg,', 'Sweden\n'],
#  ['132654,', 'Sundsvall,', 'Sweden\n'],
#  ['132655,', 'Sunne,', 'Sweden\n'],
#  ['132656,', 'Surahammar,', 'Sweden\n'],
#  ['132657,', 'Svalöv,', 'Sweden\n'],
#  ['132658,', 'Svedala,', 'Sweden\n'],
#  ['132659,', 'Sveg,', 'Sweden\n'],
#  ['132660,', 'Svenljunga,', 'Sweden\n'],
#  ['132661,', 'Säffle,', 'Sweden\n'],
#  ['132662,', 'Säter,', 'Sweden\n'],
#  ['132663,', 'Sävar,', 'Sweden\n'],
#  ['132664,', 'Sävast,', 'Sweden\n'],
#  ['132665,', 'Sävsjö,', 'Sweden\n'],
#  ['132666,', 'Söderhamn,', 'Sweden\n'],
#  ['132667,', 'Söderköping,', 'Sweden\n'],
#  ['132668,', 'Södertälje,', 'Sweden\n'],
#  ['132669,', 'Sölvesborg,', 'Sweden\n'],
#  ['132670,', 'Tanumshede,', 'Sweden\n'],
#  ['132671,', 'Tibro,', 'Sweden\n'],
#  ['132672,', 'Tidaholm,', 'Sweden\n'],
#  ['132673,', 'Tierp,', 'Sweden\n'],
#  ['132674,', 'Timrå,', 'Sweden\n'],
#  ['132675,', 'Tingsryd,', 'Sweden\n'],
#  ['132676,', 'Tomelilla,', 'Sweden\n'],
#  ['132677,', 'Torsby,', 'Sweden\n'],
#  ['132678,', 'Torsås,', 'Sweden\n'],
#  ['132679,', 'Tranemo,', 'Sweden\n'],
#  ['132680,', 'Tranås,', 'Sweden\n'],
#  ['132681,', 'Trelleborg,', 'Sweden\n'],
#  ['132682,', 'Trollhättan,', 'Sweden\n'],
#  ['132683,', 'Trosa,', 'Sweden\n'],
#  ['132684,', 'Tumba,', 'Sweden\n'],
#  ['132685,', 'Täby,', 'Sweden\n'],
#  ['132686,', 'Töcksfors,', 'Sweden\n'],
#  ['132687,', 'Töre,', 'Sweden\n'],
#  ['132688,', 'Töreboda,', 'Sweden\n'],
#  ['132689,', 'Uddevalla,', 'Sweden\n'],
#  ['132690,', 'Ulricehamn,', 'Sweden\n'],
#  ['132691,', 'Umeå,', 'Sweden\n'],
#  ['132692,', 'Upplands-Väsby,', 'Sweden\n'],
#  ['132693,', 'Uppsala,', 'Sweden\n'],
#  ['132694,', 'Ursviken,', 'Sweden\n'],
#  ['132695,', 'Vadstena,', 'Sweden\n'],
#  ['132696,', 'Vaggeryd,', 'Sweden\n'],
#  ['132697,', 'Valdemarsvik,', 'Sweden\n'],
#  ['132698,', 'Vallentuna,', 'Sweden\n'],
#  ['132699,', 'Vansbro,', 'Sweden\n'],
#  ['132700,', 'Vara,', 'Sweden\n'],
#  ['132701,', 'Varberg,', 'Sweden\n'],
#  ['132702,', 'Vaxholm,', 'Sweden\n'],
#  ['132703,', 'Vellinge,', 'Sweden\n'],
#  ['132704,', 'Vetlanda,', 'Sweden\n'],
#  ['132705,', 'Vilhelmina,', 'Sweden\n'],
#  ['132706,', 'Vimmerby,', 'Sweden\n'],
#  ['132707,', 'Vindeln,', 'Sweden\n'],
#  ['132708,', 'Vingåker,', 'Sweden\n'],
#  ['132709,', 'Visby,', 'Sweden\n'],
#  ['132710,', 'Vänersborg,', 'Sweden\n'],
#  ['132711,', 'Vännäs,', 'Sweden\n'],
#  ['132712,', 'Värnamo,', 'Sweden\n'],
#  ['132713,', 'Västerhaninge,', 'Sweden\n'],
#  ['132714,', 'Västervik,', 'Sweden\n'],
#  ['132715,', 'Västerås,', 'Sweden\n'],
#  ['132716,', 'Växjö,', 'Sweden\n'],
#  ['132717,', 'Vårgårda,', 'Sweden\n'],
#  ['132718,', 'Ystad,', 'Sweden\n'],
#  ['132719,', 'Älmhult,', 'Sweden\n'],
#  ['132720,', 'Älvdalen,', 'Sweden\n'],
#  ['132721,', 'Älvkarleby,', 'Sweden\n'],
#  ['132722,', 'Älvsbyn,', 'Sweden\n'],
#  ['132723,', 'Ängelholm,', 'Sweden\n'],
#  ['132724,', 'Åhus,', 'Sweden\n'],
#  ['132725,', 'Åkersberga,', 'Sweden\n'],
#  ['132726,', 'Åmål,', 'Sweden\n'],
#  ['132727,', 'Ånge,', 'Sweden\n'],
#  ['132728,', 'Åre,', 'Sweden\n'],
#  ['132729,', 'Årjäng,', 'Sweden\n'],
#  ['132730,', 'Åseda,', 'Sweden\n'],
#  ['132731,', 'Åsele,', 'Sweden\n'],
#  ['132732,', 'Åstorp,', 'Sweden\n'],
#  ['132733,', 'Åtvidaberg,', 'Sweden\n'],
#  ['132734,', 'Öckerö,', 'Sweden\n'],
#  ['132735,', 'Ödeshög,', 'Sweden\n'],
#  ['132736,', 'Örebro,', 'Sweden\n'],
#  ['132737,', 'Örkelljunga,', 'Sweden\n'],
#  ['132738,', 'Örnsköldsvik,', 'Sweden\n'],
#  ['132739,', 'Östersund,', 'Sweden\n'],
#  ['132740,', 'Östhammar,', 'Sweden\n'],
#  ['132741,', 'Övertorneå,', 'Sweden\n']]

# %%
def rewriting_file(filename, data):
    #data = output from final_data
    #the output is a nested list and we will convert it to string
    new_data = "".join([''.join([str(c) for c in lst]) for lst in data])
    
    with open(filename, 'w') as file:
        file.write(new_data)

# %%
#Rewriting 'city_country.csv'

rewriting_file(city_country, data_update_1)
